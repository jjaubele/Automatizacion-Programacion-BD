# %% [markdown]
# # Automatización Programación a Base de Datos

# %% [markdown]
# ## Importamos Librerias

# %%
import pandas as pd
import numpy as np
from datetime import timedelta

# %% [markdown]
# ## Definimos funciones de extracción

# %%
FIRST_ROW = 12
LAST_ROW = 61

def int_to_excel_col(n):
    result = ""
    while n > 0:
        n, remainder = divmod(n - 1, 26)
        result = chr(65 + remainder) + result
    return result

def excel_col_to_int(col):
    result = 0
    for char in col:
        result = result * 26 + (ord(char.upper()) - ord('A') + 1)
    return result

def next_excel_col(col):
    col_int = excel_col_to_int(col)
    next_col_int = col_int + 1
    return int_to_excel_col(next_col_int)

def extraer_planificacion(file, sheet):
    df_planificacion = pd.read_excel(file, sheet_name=sheet, header=None)
    df_planificacion.index = range(1, len(df_planificacion) + 1)
    df_planificacion.columns = [int_to_excel_col(i) for i in range(1, len(df_planificacion.columns) + 1)]

    return df_planificacion

def extraer_bts(file, sheet):
    df_bts = pd.read_excel(file, sheet_name=sheet, header=0)
    df_bts.index = range(1, len(df_bts) + 1)
    df_bts = df_bts[["N° Referencia", "Nombre programa", "Nombre del BT", "Abrev."]]
    df_bts.drop_duplicates(subset=["Abrev."], keep="first", inplace=True)
    
    return df_bts

def extraer_descargas(df_planificacion):
    df_descargas = pd.DataFrame({"Fecha": [], "Abrev.": [], "Volumen": [], "Columna": []})
    columnas = ["M", "S", "Y", "AE", "AK", "AQ", "AW", "BC", "BI", "BO", "BU", "CA", "CF", "CK", "CP", "CU", "DA"]
    for col in columnas:
        descargas_parciales = df_planificacion.loc[FIRST_ROW:LAST_ROW, ["B", col, next_excel_col(col)]].dropna()
        descargas_parciales.columns = ["Fecha", "Abrev.", "Volumen"]
        descargas_parciales["Columna"] = [col] * len(descargas_parciales)
        df_descargas = pd.concat([df_descargas, descargas_parciales], ignore_index=True)
    df_descargas = df_descargas[(df_descargas["Abrev."] != "Enap") & (df_descargas["Abrev."] != "Puma")]

    return df_descargas

def extraer_distancias(file, sheet):
    df_distancias = pd.read_excel(file, sheet_name=sheet, header=3, index_col=0)
    df_distancias.dropna(axis=1, how='all', inplace=True)
    df_distancias.dropna(axis=0, how='all', inplace=True)
    return df_distancias

def extraer_programas(df_planificacion):
    df_programas = df_planificacion.loc[FIRST_ROW:LAST_ROW, ["B", "J"]].dropna()
    df_programas.columns = ["Fecha", "Nombre programa"]
    return df_programas

# %% [markdown]
# ## Extracción de Información

# %%
PATH_PROGRAMACION = "Programacion Descarga Importaciones 22 de Sep.xlsx"
PATH_DISTANCIAS = "Distancias entre puertos.xlsx"

# %% [markdown]
# ### Paso 1:

# %% [markdown]
# Extraemos todos los programas, con sus respectivos buques y abreviaturas

# %%
df_bts = extraer_bts(PATH_PROGRAMACION, "Buques")
df_bts
# Out:
#    N° Referencia                       Nombre programa  \
# 1       CC 46/25                  46/25 Sakura Voyager
# 2      CC 117/25                           117/25 Yaca
# 3      CC 135/25                135/25 Seaways Kenosha
# 4       CC 19/25                          19/25 Cururo
# 5       CC 47/25                        47/25 San Jack
# 6      CC 102/25                102/25 Pintail Pacific
# 9       CC 75/25                   75/25 Flora Express
# 10      CC 21/25                  21/25 Seaways Athens
# 11      CC 48/25                      48/25 STI Mighty
# 12      CC 90/25                     90/25 Dat Mercury
# 13      CC 49/25                49/25 Pacific Sentinel
# 14     CC 118/25                     118/25 Andean Sun
# 15      CC 50/25                50/25 Pacific Kohinoor
# 16      CC 74/25                    74/25 Gem Sapphire
# 17     CC 130/25               130/25 Seaways Stamford
# 18      CC 51/25                      51/25 Jag Prachi
# 19     CC 103/25  103/25 Seaways Wheat /High Challenge
# 21     CC 119/25                 119/25 Seaways Dwarka
# 22      CC 22/25                22/25 Meridian Express
# 23      CC 52/25              52/25 Challenge Pinnacle
# 24     CC 139/25                          139/25 TBN 1
# 25      CC 53/25                           53/25 TBN 2
# 26     CC 120/25                          120/25 TBN 3
# 27     CC 138/25                          138/25 TBN 4
# 28      CC 91/25                           91/25 TBN 5
# 29      CC 54/25                           54/25 TBN 6
# 30     CC 131/25                    131/25 Mari Kokako
#
#                     Nombre del BT Abrev.
# 1                  Sakura Voyager     SV
# 2                            Yaca    Yac
# 3                 Seaways Kenosha     SK
# 4                          Cururo    Cur
# 5                        San Jack     SJ
# 6                 Pintail Pacific     PP
# 9                   Flora Express     FE
# 10                 Seaways Athens     SA
# 11                     STI Mighty     SM
# 12                    Dat Mercury     DM
# 13               Pacific Sentinel     PS
# 14                     Andean Sun     AS
# 15               Pacific Kohinoor     PK
# 16                   Gem Sapphire     GS
# 17               Seaways Stamford     SS
# 18                     Jag Prachi     JP
# 19  Seaways Wheat /High Challenge     SW
# 21                 Seaways Dwarka     SD
# 22               Meridian Express     ME
# 23             Challenge Pinnacle     CP
# 24                          TBN 1  TBN 1
# 25                          TBN 2  TBN 2
# 26                          TBN 3  TBN 3
# 27                          TBN 4  TBN 4
# 28                          TBN 5  TBN 5
# 29                          TBN 6  TBN 6
# 30                    Mari Kokako     MK

# %% [markdown]
# ### Paso 2:

# %% [markdown]
# Creamos un dataframe con los productos y las plantas presentes en la planificación.

# %%
df_productos = pd.DataFrame({"Producto": ["Diesel A1", "Gas 93", "Gas 97", "Jet A1"]})
df_plantas = pd.DataFrame({"Planta": ["PLANTA IQUIQUE", "PLANTA MEJILLONES", "PLANTA CALDERA",
                                      "TERMINAL TPI", "OXIQUIM QUINTERO", "OXIQUIM CORONEL",
                                      "PLANTA PUREO", "ENAP QUINTERO", "BT PUMA"],
                           "Ciudad": ["Iquique", "Mejillones", "Caldera", "Quintero", "Quintero",
                                      "Coronel", "Calbuco", np.nan, np.nan],
                           "Alias": ["Iquique", "Mejillones", "Caldera", "TPI", "Oxiquim Quintero",
                                      "Coronel", "Pureo", "Quintero", "Puma"]})

# %% [markdown]
# ### Paso 3:

# %% [markdown]
# Producto cruz entre plantas y productos para generar todas las combinaciones posibles.

# %%
df_productos_plantas = df_productos.merge(df_plantas, how='cross')

# %% [markdown]
# ### Paso 4:

# %% [markdown]
# Asignamos a cada par producto-planta la columna correspondiente en la planificación.

# %%
df_productos_plantas["Columna"] = ["M", "S", "Y", "AE", "BC", "BI", "BO", "BU", "CA",
                                   np.nan, "DA", np.nan, "AQ", np.nan, np.nan, np.nan, np.nan, "CK",
                                   np.nan, np.nan, np.nan, np.nan, "AW", np.nan, np.nan, np.nan, "CP",
                                   np.nan, "CU", np.nan, "AK", np.nan, np.nan, np.nan, np.nan, "CF"]

# %% [markdown]
# ### Paso 5:

# %% [markdown]
# Limpiamos el dataframe eliminando las filas sin columna asignada.

# %%
df_productos_plantas.dropna(subset=["Columna"], inplace=True)
df_productos_plantas
# Out:
#      Producto             Planta      Ciudad             Alias Columna
# 0   Diesel A1     PLANTA IQUIQUE     Iquique           Iquique       M
# 1   Diesel A1  PLANTA MEJILLONES  Mejillones        Mejillones       S
# 2   Diesel A1     PLANTA CALDERA     Caldera           Caldera       Y
# 3   Diesel A1       TERMINAL TPI    Quintero               TPI      AE
# 4   Diesel A1   OXIQUIM QUINTERO    Quintero  Oxiquim Quintero      BC
# 5   Diesel A1    OXIQUIM CORONEL     Coronel           Coronel      BI
# 6   Diesel A1       PLANTA PUREO     Calbuco             Pureo      BO
# 7   Diesel A1      ENAP QUINTERO         NaN          Quintero      BU
# 8   Diesel A1            BT PUMA         NaN              Puma      CA
# 10     Gas 93  PLANTA MEJILLONES  Mejillones        Mejillones      DA
# 12     Gas 93       TERMINAL TPI    Quintero               TPI      AQ
# 17     Gas 93            BT PUMA         NaN              Puma      CK
# 22     Gas 97   OXIQUIM QUINTERO    Quintero  Oxiquim Quintero      AW
# 26     Gas 97            BT PUMA         NaN              Puma      CP
# 28     Jet A1  PLANTA MEJILLONES  Mejillones        Mejillones      CU
# 30     Jet A1       TERMINAL TPI    Quintero               TPI      AK
# 35     Jet A1            BT PUMA         NaN              Puma      CF

# %% [markdown]
# ### Paso 6:

# %% [markdown]
# Extraemos la planificación y sus respectivas descargas. Se ignoran descargas realizadas por el Puma y Enap.

# %%
df_planificacion = extraer_planificacion(PATH_PROGRAMACION, "Planificación")
df_descargas = extraer_descargas(df_planificacion)
df_descargas
# Out:
# c:\Users\jaubele.ap\AppData\Local\Programs\Python\Python313\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Conditional Formatting extension is not supported and will be removed
#   warn(msg)
# c:\Users\jaubele.ap\AppData\Local\Programs\Python\Python313\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
#                    Fecha   Abrev. Volumen Columna
# 0    2025-09-25 00:00:00       FE    4000       M
# 1    2025-09-26 00:00:00       FE    4000       M
# 2    2025-09-30 00:00:00       SM    6000       M
# 3    2025-10-01 00:00:00       SM    6000       M
# 5    2025-10-14 00:00:00       PK    6000       M
# ..                   ...      ...     ...     ...
# 120  2025-11-01 00:00:00  Caldera   -6000      CA
# 121  2025-09-23 00:00:00       PP   15260      CK
# 122  2025-10-06 00:00:00      TPI  -13000      CK
# 123  2025-10-10 00:00:00      TPI   -9245      CK
# 124  2025-10-26 00:00:00      TPI    8200      CK
#
# [92 rows x 4 columns]

# %% [markdown]
# ### Paso 7:

# %% [markdown]
# Mediante la el atributo "Columna" asociamos cada descarga a un par producto-planta.

# %%
df_descargas_productos_plantas = df_descargas.merge(df_productos_plantas, on=["Columna"]).drop(columns=["Columna"])
df_descargas_productos_plantas
# Out:
#                   Fecha   Abrev. Volumen   Producto          Planta   Ciudad  \
# 0   2025-09-25 00:00:00       FE    4000  Diesel A1  PLANTA IQUIQUE  Iquique
# 1   2025-09-26 00:00:00       FE    4000  Diesel A1  PLANTA IQUIQUE  Iquique
# 2   2025-09-30 00:00:00       SM    6000  Diesel A1  PLANTA IQUIQUE  Iquique
# 3   2025-10-01 00:00:00       SM    6000  Diesel A1  PLANTA IQUIQUE  Iquique
# 4   2025-10-14 00:00:00       PK    6000  Diesel A1  PLANTA IQUIQUE  Iquique
# ..                  ...      ...     ...        ...             ...      ...
# 87  2025-11-01 00:00:00  Caldera   -6000  Diesel A1         BT PUMA      NaN
# 88  2025-09-23 00:00:00       PP   15260     Gas 93         BT PUMA      NaN
# 89  2025-10-06 00:00:00      TPI  -13000     Gas 93         BT PUMA      NaN
# 90  2025-10-10 00:00:00      TPI   -9245     Gas 93         BT PUMA      NaN
# 91  2025-10-26 00:00:00      TPI    8200     Gas 93         BT PUMA      NaN
#
#       Alias
# 0   Iquique
# 1   Iquique
# 2   Iquique
# 3   Iquique
# 4   Iquique
# ..      ...
# 87     Puma
# 88     Puma
# 89     Puma
# 90     Puma
# 91     Puma
#
# [92 rows x 7 columns]

# %% [markdown]
# ### Paso 8:

# %% [markdown]
# Mediante la abreviatura asociamos cada descarga a un programa (Por esto es importante que la abreviatura sea única, o en su defecto utilizar otro atributo de carater único como correlativo o nombre de programa).
# Se eliminarán todas las descargas que no tengan la abreviatura de un buque asociada (Ej: Caldera o TPI hacia el Puma).

# %%
df_descargas_completo = df_descargas_productos_plantas.merge(df_bts, on=["Abrev."]).drop(columns=["Abrev."])
df_descargas_completo
# Out:
#                   Fecha Volumen   Producto           Planta   Ciudad    Alias  \
# 0   2025-09-25 00:00:00    4000  Diesel A1   PLANTA IQUIQUE  Iquique  Iquique
# 1   2025-09-26 00:00:00    4000  Diesel A1   PLANTA IQUIQUE  Iquique  Iquique
# 2   2025-09-30 00:00:00    6000  Diesel A1   PLANTA IQUIQUE  Iquique  Iquique
# 3   2025-10-01 00:00:00    6000  Diesel A1   PLANTA IQUIQUE  Iquique  Iquique
# 4   2025-10-14 00:00:00    6000  Diesel A1   PLANTA IQUIQUE  Iquique  Iquique
# ..                  ...     ...        ...              ...      ...      ...
# 70  2025-10-14 00:00:00    9000  Diesel A1  OXIQUIM CORONEL  Coronel  Coronel
# 71  2025-10-15 00:00:00    9000  Diesel A1  OXIQUIM CORONEL  Coronel  Coronel
# 72  2025-10-27 00:00:00    7500  Diesel A1  OXIQUIM CORONEL  Coronel  Coronel
# 73  2025-10-28 00:00:00    7500  Diesel A1  OXIQUIM CORONEL  Coronel  Coronel
# 74  2025-09-23 00:00:00   15260     Gas 93          BT PUMA      NaN     Puma
#
#    N° Referencia          Nombre programa     Nombre del BT
# 0       CC 75/25      75/25 Flora Express     Flora Express
# 1       CC 75/25      75/25 Flora Express     Flora Express
# 2       CC 48/25         48/25 STI Mighty        STI Mighty
# 3       CC 48/25         48/25 STI Mighty        STI Mighty
# 4       CC 50/25   50/25 Pacific Kohinoor  Pacific Kohinoor
# ..           ...                      ...               ...
# 70     CC 118/25        118/25 Andean Sun        Andean Sun
# 71     CC 118/25        118/25 Andean Sun        Andean Sun
# 72     CC 130/25  130/25 Seaways Stamford  Seaways Stamford
# 73     CC 130/25  130/25 Seaways Stamford  Seaways Stamford
# 74     CC 102/25   102/25 Pintail Pacific   Pintail Pacific
#
# [75 rows x 9 columns]

# %% [markdown]
# ### Paso 9:

# %% [markdown]
# Agrupamos todas las descargas de un programa que son en días consecutivos de un mismo producto y en una misma planta como una sola descarga.

# %%
df_descargas_completo = df_descargas_completo[["Fecha", "N° Referencia", "Nombre programa", "Nombre del BT",
                                               "Producto", "Planta", "Ciudad", "Alias", "Volumen"]]

df_descargas_completo["Fecha"] = pd.to_datetime(df_descargas_completo["Fecha"])
df_descargas_completo["diff"] = (
    df_descargas_completo.groupby(["Nombre programa", "Producto", "Planta"])["Fecha"]
    .diff()
    .dt.days
)

df_descargas_completo["Grupo"] = (df_descargas_completo["diff"] != 1).cumsum()
df_descargas_agrupadas = (
    df_descargas_completo.groupby("Grupo", as_index=False).agg({
        "Fecha": ["min", "max"],   # rango de fechas
        "Volumen": "sum"
    })
)
df_descargas_agrupadas.columns = ["Grupo", "Fecha inicio", "Fecha fin", "Volumen total"]

df_descargas_completo_sin_duplicados = df_descargas_completo.drop_duplicates(subset=["Grupo"])
df_descargas_agrupadas = df_descargas_agrupadas.merge(
    df_descargas_completo_sin_duplicados, on="Grupo").drop(columns=["diff", "Fecha", "Volumen"])
df_descargas_agrupadas = df_descargas_agrupadas[[
    "Nombre programa", "N° Referencia", "Nombre del BT", "Producto", "Planta", "Ciudad", "Alias",
    "Fecha inicio", "Fecha fin", "Volumen total"]]

# Ordenar por Nombre programa y Fecha inicio, y agregar N° Descarga
df_descargas_agrupadas = df_descargas_agrupadas.sort_values(by=["Nombre programa", "Fecha inicio"])
df_descargas_agrupadas["N° Descarga"] = (
    df_descargas_agrupadas.groupby("Nombre programa").cumcount() + 1
)
df_descargas_agrupadas
# Out:
#                          Nombre programa N° Referencia  \
# 37                102/25 Pintail Pacific     CC 102/25
# 30                102/25 Pintail Pacific     CC 102/25
# 32  103/25 Seaways Wheat /High Challenge     CC 103/25
# 31  103/25 Seaways Wheat /High Challenge     CC 103/25
# 8                      118/25 Andean Sun     CC 118/25
# 35                     118/25 Andean Sun     CC 118/25
# 3                  119/25 Seaways Dwarka     CC 119/25
# 12                 119/25 Seaways Dwarka     CC 119/25
# 25               130/25 Seaways Stamford     CC 130/25
# 36               130/25 Seaways Stamford     CC 130/25
# 23                135/25 Seaways Kenosha     CC 135/25
# 10                135/25 Seaways Kenosha     CC 135/25
# 27                          139/25 TBN 1     CC 139/25
# 14                          139/25 TBN 1     CC 139/25
# 20                          19/25 Cururo      CC 19/25
# 34                          19/25 Cururo      CC 19/25
# 33                  21/25 Seaways Athens      CC 21/25
# 22                  21/25 Seaways Athens      CC 21/25
# 13                22/25 Meridian Express      CC 22/25
# 4                 22/25 Meridian Express      CC 22/25
# 18                     Jag Prachi  Diesel A1     PLANTA CALDERA     Caldera
# 26                     Jag Prachi  Diesel A1       TERMINAL TPI    Quintero
# 28             Challenge Pinnacle  Diesel A1       TERMINAL TPI    Quintero
# 19             Challenge Pinnacle  Diesel A1     PLANTA CALDERA     Caldera
# 17                   Gem Sapphire  Diesel A1     PLANTA CALDERA     Caldera
# 11                   Gem Sapphire  Diesel A1  PLANTA MEJILLONES  Mejillones
# 0                   Flora Express  Diesel A1     PLANTA IQUIQUE     Iquique
# 21                  Flora Express  Diesel A1       TERMINAL TPI    Quintero
# 29                    Dat Mercury     Jet A1       TERMINAL TPI    Quintero
#
#                Alias Fecha inicio  Fecha fin Volumen total  N° Descarga
# 37              Puma   2025-09-23 2025-09-23         15260            1
# 30               TPI   2025-09-25 2025-09-25         34000            2
# 32  Oxiquim Quintero   2025-10-23 2025-10-24          8000            1
# 31               TPI   2025-10-28 2025-10-29         40000            2
# 8         Mejillones   2025-10-09 2025-10-10         30000            1
# 35           Coronel   2025-10-14 2025-10-15         18000            2
# 3            Iquique   2025-10-23 2025-10-24         12000            1
# 12        Mejillones   2025-10-28 2025-10-29         36000            2
# 25               TPI   2025-10-23 2025-10-24         32000            1
# 36           Coronel   2025-10-27 2025-10-28         15000            2
# 23               TPI   2025-10-14 2025-10-15         24000            1
# 10        Mejillones   2025-10-18 2025-10-19         24000            2
# 27               TPI   2025-11-01 2025-11-02         24000            1
# 14        Mejillones   2025-11-07 2025-11-08         24000            2
# 20               TPI   2025-09-26 2025-09-27         30000            1
# 34           Coronel   2025-09-29 2025-09-30         18000            2
# 33  Oxiquim Quintero   2025-10-04 2025-10-05         15000            1
# 22               TPI   2025-10-07 2025-10-08         33000            2
# 13        Mejillones   2025-11-02 2025-11-03         36000            1
# 4            Iquique   2025-11-06 2025-11-07         12000            2
# 5         Mejillones   2025-09-25 2025-09-26         37600            1
# 6         Mejillones   2025-09-28 2025-09-29         36000            1
# 15           Caldera   2025-10-01 2025-10-02         10117            2
# 1            Iquique   2025-09-30 2025-10-01         12000            1
# 7         Mejillones   2025-10-04 2025-10-05         36000            2
# 16           Caldera   2025-10-09 2025-10-10         12000            1
# 9         Mejillones   2025-10-14 2025-10-15         36000            2
# 2            Iquique   2025-10-14 2025-10-15         12000            1
# 24               TPI   2025-10-18 2025-10-19         36000            2
# 18           Caldera   2025-10-25 2025-10-26         12000            1
# 26               TPI   2025-10-28 2025-10-29         36000            2
# 28               TPI   2025-11-06 2025-11-07         36000            1
# 19           Caldera   2025-11-08 2025-11-09         12000            2
# 17           Caldera   2025-10-16 2025-10-17         12000            1
# 11        Mejillones   2025-10-23 2025-10-24         36000            2
# 0            Iquique   2025-09-25 2025-09-26          8000            1
# 21               TPI   2025-10-03 2025-10-04         42398            2
# 29               TPI   2025-10-11 2025-10-13         48000            1

# %% [markdown]
# ### Paso 10:

# %% [markdown]
# Extraemos todos los programas de la planificación.

# %%
df_programas = extraer_programas(df_planificacion)
df_programas.columns = ["ETA", "Nombre programa"]
df_programas
# Out:
#                     ETA                       Nombre programa
# 16  2025-09-25 00:00:00                   75/25 Flora Express
# 20  2025-09-29 00:00:00                      48/25 STI Mighty
# 22  2025-10-01 00:00:00                  21/25 Seaways Athens
# 27  2025-10-06 00:00:00                     118/25 Andean Sun
# 28  2025-10-07 00:00:00                49/25 Pacific Sentinel
# 31  2025-10-10 00:00:00                     90/25 Dat Mercury
# 34  2025-10-13 00:00:00                50/25 Pacific Kohinoor
# 35  2025-10-14 00:00:00                 20/25 Seaways Kolberg
# 36  2025-10-15 00:00:00                    74/25 Gem Sapphire
# 37  2025-10-16 00:00:00               130/25 Seaways Stamford
# 42  2025-10-21 00:00:00                      51/25 Jag Prachi
# 43  2025-10-22 00:00:00                 119/25 Seaways Dwarka
# 44  2025-10-23 00:00:00  103/25 Seaways Wheat /High Challenge
# 49  2025-10-28 00:00:00                          139/25 TBN 1
# 50  2025-10-29 00:00:00                22/25 Meridian Express
# 51  2025-10-30 00:00:00              52/25 Challenge Pinnacle

# %% [markdown]
# ### Paso 10:

# %% [markdown]
# Asociamos a cada programa sus respectivas descargas, agregamos la ETA a la primera descarga de cada programa.

# %% [markdown]
# * Nota Importante: Esto ignorará todas las descargas asociadas a programas cuya ETA estimada sea anterior al inicio de la programación.

# %%
df_descargas_agrupadas = df_programas.merge(df_descargas_agrupadas, on="Nombre programa")
df_descargas_agrupadas["ETA"] = df_descargas_agrupadas["ETA"][[True if descarga == 1 else False for descarga in df_descargas_agrupadas["N° Descarga"]]]
df_descargas_agrupadas
# Out:
#                     ETA                       Nombre programa N° Referencia  \
# 0   2025-09-25 00:00:00                   75/25 Flora Express      CC 75/25
# 1                   NaN                   75/25 Flora Express      CC 75/25
# 2   2025-09-29 00:00:00                      48/25 STI Mighty      CC 48/25
# 3                   NaN                      48/25 STI Mighty      CC 48/25
# 4   2025-10-01 00:00:00                  21/25 Seaways Athens      CC 21/25
# 5                   NaN                  21/25 Seaways Athens      CC 21/25
# 6   2025-10-06 00:00:00                     118/25 Andean Sun     CC 118/25
# 7                   NaN                     118/25 Andean Sun     CC 118/25
# 8   2025-10-07 00:00:00                49/25 Pacific Sentinel      CC 49/25
# 9                   NaN                49/25 Pacific Sentinel      CC 49/25
# 10  2025-10-10 00:00:00                     90/25 Dat Mercury      CC 90/25
# 11  2025-10-13 00:00:00                50/25 Pacific Kohinoor      CC 50/25
# 12                  NaN                50/25 Pacific Kohinoor      CC 50/25
# 13  2025-10-15 00:00:00                    74/25 Gem Sapphire      CC 74/25
# 14                  NaN                    74/25 Gem Sapphire      CC 74/25
# 15  2025-10-16 00:00:00               130/25 Seaways Stamford     CC 130/25
# 16                  NaN               130/25 Seaways Stamford     CC 130/25
# 17  2025-10-21 00:00:00                      51/25 Jag Prachi      CC 51/25
# 18                  NaN                      51/25 Jag Prachi      CC 51/25
# 19  2025-10-22 00:00:00                 119/25 Seaways Dwarka     CC 119/25
# 20                  NaN                 119/25 Seaways Dwarka     CC 119/25
# 6         Mejillones   2025-10-09 2025-10-10         30000            1
# 7            Coronel   2025-10-14 2025-10-15         18000            2
# 8            Caldera   2025-10-09 2025-10-10         12000            1
# 9         Mejillones   2025-10-14 2025-10-15         36000            2
# 10               TPI   2025-10-11 2025-10-13         48000            1
# 11           Iquique   2025-10-14 2025-10-15         12000            1
# 12               TPI   2025-10-18 2025-10-19         36000            2
# 13           Caldera   2025-10-16 2025-10-17         12000            1
# 14        Mejillones   2025-10-23 2025-10-24         36000            2
# 15               TPI   2025-10-23 2025-10-24         32000            1
# 16           Coronel   2025-10-27 2025-10-28         15000            2
# 17           Caldera   2025-10-25 2025-10-26         12000            1
# 18               TPI   2025-10-28 2025-10-29         36000            2
# 19           Iquique   2025-10-23 2025-10-24         12000            1
# 20        Mejillones   2025-10-28 2025-10-29         36000            2
# 21  Oxiquim Quintero   2025-10-23 2025-10-24          8000            1
# 22               TPI   2025-10-28 2025-10-29         40000            2
# 23               TPI   2025-11-01 2025-11-02         24000            1
# 24        Mejillones   2025-11-07 2025-11-08         24000            2
# 25        Mejillones   2025-11-02 2025-11-03         36000            1
# 26           Iquique   2025-11-06 2025-11-07         12000            2
# 27               TPI   2025-11-06 2025-11-07         36000            1
# 28           Caldera   2025-11-08 2025-11-09         12000            2

# %% [markdown]
# ### Paso 11:

# %% [markdown]
# Extraer matriz de distancias y pasar a tiempos aproximando en horas al entero superior

# %%
matriz_de_distancias = extraer_distancias(PATH_DISTANCIAS, "Datos")
VELOCIDAD_MEDIA = 12  # nudos
# Calcular matriz de tiempos aproximando en horas al entero superior
matriz_de_tiempos = np.ceil(matriz_de_distancias / VELOCIDAD_MEDIA).astype(int)
matriz_de_tiempos
# Out:
#               ARICA  IQUIQUE  TOCOPILLA  MEJILLONES  ANTOFAGASTA  BARQUITO  \
# Arica             0        9         19          24           28        40
# Iquique           9        0         10          15           19        32
# Tocopilla        19       10          0           6           10        23
# Mejillones       24       15          6           0            6        19
# Antofagasta      28       19         10           6            0        15
# Barquito         40       32         23          19           15         0
# Caldera          44       35         26          22           18         5
# Huasco           51       43         33          30           26        12
# Guayacan         59       51         41          38           34        20
# Quintero         73       64         55          51           48        33
# San Vicente      93       85         75          72           68        54
# Coronel          95       87         77          74           70        56
# Puerto Montt    124      116        107         102           99        86
# Calbuco         122      113        104         100           97        83
# Chacabuco       141      133        123         119          116       102
# Punta Arenas    192      183        174         170          166       153
# Cabo Negro      193      185        175         172          168       154
#
#               CALDERA  HUASCO  GUAYACAN  QUINTERO  SAN VICENTE  CORONEL  \
# Arica              44      51        59        73           93       95
# Iquique            35      43        51        64           85       87
# Tocopilla          26      33        41        55           75       77
# Mejillones         22      30        38        51           72       74
# Antofagasta        18      26        34        48           68       70
# Barquito            5      12        20        33           54       56
# Caldera             0       8        17        31           51       53
# Huasco              8       0         9        23           44       46
# Guayacan           17       9         0        16           36       38
# Quintero           31      23        16         0           22       24
# San Vicente        51      44        36        22            0        3
# Coronel            53      46        38        24            3        0
# Puerto Montt       82      75        67        54           33       32
# Calbuco            80      72        65        51           31       30
# Chacabuco          99      92        84        70           50       49
# Punta Arenas      149     142       135       121          100       99
# Cabo Negro        151     143       136       122          102      101
#
#               PUERTO MONTT  CALBUCO  CHACABUCO  PUNTA ARENAS  CABO NEGRO
# Arica                  124      122        141           192         193
# Iquique                116      113        133           183         185
# Tocopilla              107      104        123           174         175
# Mejillones             102      100        119           170         172
# Antofagasta             99       97        116           166         168
# Barquito                86       83        102           153         154
# Caldera                 82       80         99           149         151
# Huasco                  75       72         92           142         143
# Guayacan                67       65         84           135         136
# Quintero                54       51         70           121         122
# San Vicente             33       31         50           100         102
# Coronel                 32       30         49            99         101
# Puerto Montt             0        2         63            78          79
# Calbuco                  2        0         21            76          77
# Chacabuco               63       21          0            63          65
# Punta Arenas            78       76         63             0           2
# Cabo Negro              79       77         65             2           0

# %% [markdown]
# ### Paso 12:

# %% [markdown]
# Calcular ETAs según matriz de tiempos

# %%
def rellenar_etas(df_descargas, df_tiempos):
    # Copiamos para no modificar el original
    df = df_descargas.copy()
    
    for programa, group in df.groupby('Nombre programa'):
        group = group.sort_values('N° Descarga').copy()
        for i in range(len(group)):
            if pd.isna(group.iloc[i]['ETA']):
                if i == 0:
                    continue  # No hay anterior
                prev = group.iloc[i-1]
                ciudad_origen = prev['Ciudad']
                ciudad_destino = group.iloc[i]['Ciudad']

                # Hora de salida: fecha fin anterior a las 23:00
                hora_salida = prev['Fecha fin'].replace(hour=23, minute=0, second=0)
                
                if pd.isna(ciudad_origen) or pd.isna(ciudad_destino):
                    df.loc[group.index[i], 'ETA'] = hora_salida
                    continue
                
                # Horas de viaje desde la matriz
                horas_viaje = df_tiempos.loc[ciudad_origen, ciudad_destino.upper()]
                horas_viaje = horas_viaje
                
                # Rellenar ETA
                df.loc[group.index[i], 'ETA'] = hora_salida + timedelta(hours=int(horas_viaje))

    return df

# %%
df_descargas_agrupadas = rellenar_etas(df_descargas_agrupadas, matriz_de_tiempos)
df_descargas_agrupadas
# Out:
#                     ETA                       Nombre programa N° Referencia  \
# 0   2025-09-25 00:00:00                   75/25 Flora Express      CC 75/25
# 1   2025-09-29 15:00:00                   75/25 Flora Express      CC 75/25
# 2   2025-09-29 00:00:00                      48/25 STI Mighty      CC 48/25
# 3   2025-10-02 14:00:00                      48/25 STI Mighty      CC 48/25
# 4   2025-10-01 00:00:00                  21/25 Seaways Athens      CC 21/25
# 5   2025-10-05 23:00:00                  21/25 Seaways Athens      CC 21/25
# 6   2025-10-06 00:00:00                     118/25 Andean Sun     CC 118/25
# 7   2025-10-14 01:00:00                     118/25 Andean Sun     CC 118/25
# 8   2025-10-07 00:00:00                49/25 Pacific Sentinel      CC 49/25
# 9   2025-10-11 21:00:00                49/25 Pacific Sentinel      CC 49/25
# 10  2025-10-10 00:00:00                     90/25 Dat Mercury      CC 90/25
# 11  2025-10-13 00:00:00                50/25 Pacific Kohinoor      CC 50/25
# 23                          TBN 1  Diesel A1       TERMINAL TPI    Quintero
# 24                          TBN 1  Diesel A1  PLANTA MEJILLONES  Mejillones
# 25               Meridian Express  Diesel A1  PLANTA MEJILLONES  Mejillones
# 26               Meridian Express  Diesel A1     PLANTA IQUIQUE     Iquique
# 27             Challenge Pinnacle  Diesel A1       TERMINAL TPI    Quintero
# 28             Challenge Pinnacle  Diesel A1     PLANTA CALDERA     Caldera
#
#                Alias Fecha inicio  Fecha fin Volumen total  N° Descarga
# 0            Iquique   2025-09-25 2025-09-26          8000            1
# 1                TPI   2025-10-03 2025-10-04         42398            2
# 2            Iquique   2025-09-30 2025-10-01         12000            1
# 3         Mejillones   2025-10-04 2025-10-05         36000            2
# 4   Oxiquim Quintero   2025-10-04 2025-10-05         15000            1
# 5                TPI   2025-10-07 2025-10-08         33000            2
# 6         Mejillones   2025-10-09 2025-10-10         30000            1
# 7            Coronel   2025-10-14 2025-10-15         18000            2
# 8            Caldera   2025-10-09 2025-10-10         12000            1
# 9         Mejillones   2025-10-14 2025-10-15         36000            2
# 10               TPI   2025-10-11 2025-10-13         48000            1
# 11           Iquique   2025-10-14 2025-10-15         12000            1
# 12               TPI   2025-10-18 2025-10-19         36000            2
# 13           Caldera   2025-10-16 2025-10-17         12000            1
# 14        Mejillones   2025-10-23 2025-10-24         36000            2
# 15               TPI   2025-10-23 2025-10-24         32000            1
# 16           Coronel   2025-10-27 2025-10-28         15000            2
# 17           Caldera   2025-10-25 2025-10-26         12000            1
# 18               TPI   2025-10-28 2025-10-29         36000            2
# 19           Iquique   2025-10-23 2025-10-24         12000            1
# 20        Mejillones   2025-10-28 2025-10-29         36000            2
# 21  Oxiquim Quintero   2025-10-23 2025-10-24          8000            1
# 22               TPI   2025-10-28 2025-10-29         40000            2
# 23               TPI   2025-11-01 2025-11-02         24000            1
# 24        Mejillones   2025-11-07 2025-11-08         24000            2
# 25        Mejillones   2025-11-02 2025-11-03         36000            1
# 26           Iquique   2025-11-06 2025-11-07         12000            2
# 27               TPI   2025-11-06 2025-11-07         36000            1
# 28           Caldera   2025-11-08 2025-11-09         12000            2

# %% [markdown]
# ### Paso 13:

# %% [markdown]
# Ajustamos al formato de la Base de Datos.

# %%
df_BD = df_descargas_agrupadas[["N° Referencia", "Nombre del BT", "Producto", "Alias", "Volumen total", "ETA", "Fecha fin"]]
df_BD.columns = ["CC", "Nombre BT", "Producto", "Puerto", "Volumen", "ETA", "Fin descarga"]
df_BD
# Out:
#            CC                      Nombre BT   Producto            Puerto  \
# 0    CC 75/25                  Flora Express  Diesel A1           Iquique
# 1    CC 75/25                  Flora Express  Diesel A1               TPI
# 2    CC 48/25                     STI Mighty  Diesel A1           Iquique
# 3    CC 48/25                     STI Mighty  Diesel A1        Mejillones
# 4    CC 21/25                 Seaways Athens  Diesel A1  Oxiquim Quintero
# 5    CC 21/25                 Seaways Athens  Diesel A1               TPI
# 6   CC 118/25                     Andean Sun  Diesel A1        Mejillones
