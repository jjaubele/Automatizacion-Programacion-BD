# %% [markdown]
# # Automatización Programación a Base de Datos

# %% [markdown]
# ## Importamos Librerias

# %%
import pandas as pd
import numpy as np
import calendar
from datetime import timedelta

# %% [markdown]
# ## Definimos funciones para lectura de Excel

# %%
def int_to_excel_col(n):
    result = ""
    while n > 0:
        n, remainder = divmod(n - 1, 26)
        result = chr(65 + remainder) + result
    return result

def excel_col_to_int(col):
    result = 0
    for char in col:
        result = result * 26 + (ord(char.upper()) - ord('A') + 1)
    return result

def next_excel_col(col):
    col_int = excel_col_to_int(col)
    next_col_int = col_int + 1
    return int_to_excel_col(next_col_int)

# %% [markdown]
# ## Parte 1:

# %% [markdown]
# Completar campos de CC, Nombre BT, Producto, Puerto, Volumen, ETA y Fin descarga.

# %%
PATH_PROGRAMACION = "Programacion Descarga Importaciones 22 de Sep.xlsx"
PATH_DISTANCIAS = "Distancias entre puertos.xlsx"

# %% [markdown]
# ### Paso 1:

# %% [markdown]
# Extraemos todos los programas, con sus respectivos buques y abreviaturas

# %% [markdown]
# - Problema: Abreviaturas duplicadas en hoja de buques (Seaways Kenosha-Seaways Kolberg).

# %%
def extraer_bts(file, sheet):
    df_bts = pd.read_excel(file, sheet_name=sheet, header=0)
    df_bts.index = range(1, len(df_bts) + 1)
    df_bts = df_bts[["N° Referencia", "Nombre programa", "Nombre del BT", "Abrev."]]
    df_bts.drop_duplicates(subset=["N° Referencia"], keep="first", inplace=True)
    
    return df_bts

# %%
df_bts = extraer_bts(PATH_PROGRAMACION, "Buques")
df_bts.index = range(1, len(df_bts) + 1)
df_bts
# Out:
#    N° Referencia                       Nombre programa  \
# 1      CC 135/25                135/25 Seaways Kenosha
# 2      CC 117/25                           117/25 Yaca
# 3       CC 46/25                  46/25 Sakura Voyager
# 4       CC 19/25                          19/25 Cururo
# 5       CC 47/25                        47/25 San Jack
# 6      CC 102/25                102/25 Pintail Pacific
# 7       CC 75/25                   75/25 Flora Express
# 8       CC 20/25                 20/25 Seaways Kolberg
# 9       CC 48/25                      48/25 STI Mighty
# 10      CC 21/25                  21/25 Seaways Athens
# 11      CC 90/25                     90/25 Dat Mercury
# 12     CC 118/25                     118/25 Andean Sun
# 13      CC 49/25                49/25 Pacific Sentinel
# 14      CC 50/25                50/25 Pacific Kohinoor
# 15      CC 74/25                    74/25 Gem Sapphire
# 16     CC 130/25               130/25 Seaways Stamford
# 17      CC 51/25                      51/25 Jag Prachi
# 18     CC 103/25  103/25 Seaways Wheat /High Challenge
# 19     CC 119/25                 119/25 Seaways Dwarka
# 20      CC 52/25              52/25 Challenge Pinnacle
# 21      CC 22/25                22/25 Meridian Express
# 22     CC 139/25                          139/25 TBN 1
# 23      CC 53/25                           53/25 TBN 2
# 24     CC 120/25                          120/25 TBN 3
# 25     CC 138/25                          138/25 TBN 4
# 26      CC 91/25                           91/25 TBN 5
# 27      CC 54/25                           54/25 TBN 6
# 28     CC 131/25                    131/25 Mari Kokako
#
#                     Nombre del BT Abrev.
# 1                 Seaways Kenosha    SKE
# 2                            Yaca    Yac
# 3                  Sakura Voyager     SV
# 4                          Cururo    Cur
# 5                        San Jack     SJ
# 6                 Pintail Pacific     PP
# 7                   Flora Express     FE
# 8                 Seaways Kolberg     SK
# 9                      STI Mighty     SM
# 10                 Seaways Athens     SA
# 11                    Dat Mercury     DM
# 12                     Andean Sun     AS
# 13               Pacific Sentinel     PS
# 14               Pacific Kohinoor     PK
# 15                   Gem Sapphire     GS
# 16               Seaways Stamford     SS
# 17                     Jag Prachi     JP
# 18  Seaways Wheat /High Challenge     SW
# 19                 Seaways Dwarka     SD
# 20             Challenge Pinnacle     CP
# 21               Meridian Express     ME
# 22                          TBN 1  TBN 1
# 23                          TBN 2  TBN 2
# 24                          TBN 3  TBN 3
# 25                          TBN 4  TBN 4
# 26                          TBN 5  TBN 5
# 27                          TBN 6  TBN 6
# 28                    Mari Kokako     MK

# %% [markdown]
# ### Paso 2:

# %% [markdown]
# Creamos un dataframe con los productos y las plantas presentes en la planificación.

# %% [markdown]
# * Se asocia la ciudad de calbuco a la planta pureo.
# * Alias según formato utilizado en la base de datos de estimación semanal.

# %%
df_productos = pd.DataFrame({"Producto": ["Diesel A1", "Gas 93", "Gas 97", "Jet A1"]})
df_plantas = pd.DataFrame({"Planta": ["PLANTA IQUIQUE", "PLANTA MEJILLONES", "PLANTA CALDERA",
                                      "TERMINAL TPI", "OXIQUIM QUINTERO", "OXIQUIM CORONEL",
                                      "PLANTA PUREO", "ENAP QUINTERO", "BT PUMA"],
                           "Ciudad": ["Iquique", "Mejillones", "Caldera", "Quintero", "Quintero",
                                      "Coronel", "Calbuco", np.nan, np.nan],
                           "Alias": ["Iquique", "Mejillones", "Caldera", "TPI", "Oxiquim Quintero",
                                      "Coronel", "Pureo", "Quintero", "Puma"]})
df_plantas.index = range(1, len(df_plantas) + 1)
df_plantas
# Out:
#               Planta      Ciudad             Alias
# 1     PLANTA IQUIQUE     Iquique           Iquique
# 2  PLANTA MEJILLONES  Mejillones        Mejillones
# 3     PLANTA CALDERA     Caldera           Caldera
# 4       TERMINAL TPI    Quintero               TPI
# 5   OXIQUIM QUINTERO    Quintero  Oxiquim Quintero
# 6    OXIQUIM CORONEL     Coronel           Coronel
# 7       PLANTA PUREO     Calbuco             Pureo
# 8      ENAP QUINTERO         NaN          Quintero
# 9            BT PUMA         NaN              Puma

# %% [markdown]
# ### Paso 3:

# %% [markdown]
# Producto cruz entre plantas y productos para generar todas las combinaciones posibles.

# %%
df_productos_plantas = df_productos.merge(df_plantas, how='cross')
df_productos_plantas.index = range(1, len(df_productos_plantas) + 1)
df_productos_plantas
# Out:
#      Producto             Planta      Ciudad             Alias
# 1   Diesel A1     PLANTA IQUIQUE     Iquique           Iquique
# 2   Diesel A1  PLANTA MEJILLONES  Mejillones        Mejillones
# 3   Diesel A1     PLANTA CALDERA     Caldera           Caldera
# 4   Diesel A1       TERMINAL TPI    Quintero               TPI
# 5   Diesel A1   OXIQUIM QUINTERO    Quintero  Oxiquim Quintero
# 6   Diesel A1    OXIQUIM CORONEL     Coronel           Coronel
# 7   Diesel A1       PLANTA PUREO     Calbuco             Pureo
# 8   Diesel A1      ENAP QUINTERO         NaN          Quintero
# 9   Diesel A1            BT PUMA         NaN              Puma
# 10     Gas 93     PLANTA IQUIQUE     Iquique           Iquique
# 11     Gas 93  PLANTA MEJILLONES  Mejillones        Mejillones
# 12     Gas 93     PLANTA CALDERA     Caldera           Caldera
# 13     Gas 93       TERMINAL TPI    Quintero               TPI
# 14     Gas 93   OXIQUIM QUINTERO    Quintero  Oxiquim Quintero
# 15     Gas 93    OXIQUIM CORONEL     Coronel           Coronel
# 16     Gas 93       PLANTA PUREO     Calbuco             Pureo
# 17     Gas 93      ENAP QUINTERO         NaN          Quintero
# 18     Gas 93            BT PUMA         NaN              Puma
# 19     Gas 97     PLANTA IQUIQUE     Iquique           Iquique
# 20     Gas 97  PLANTA MEJILLONES  Mejillones        Mejillones
# 21     Gas 97     PLANTA CALDERA     Caldera           Caldera
# 22     Gas 97       TERMINAL TPI    Quintero               TPI
# 23     Gas 97   OXIQUIM QUINTERO    Quintero  Oxiquim Quintero
# 24     Gas 97    OXIQUIM CORONEL     Coronel           Coronel
# 25     Gas 97       PLANTA PUREO     Calbuco             Pureo
# 26     Gas 97      ENAP QUINTERO         NaN          Quintero
# 27     Gas 97            BT PUMA         NaN              Puma
# 28     Jet A1     PLANTA IQUIQUE     Iquique           Iquique
# 29     Jet A1  PLANTA MEJILLONES  Mejillones        Mejillones
# 30     Jet A1     PLANTA CALDERA     Caldera           Caldera
# 31     Jet A1       TERMINAL TPI    Quintero               TPI
# 32     Jet A1   OXIQUIM QUINTERO    Quintero  Oxiquim Quintero
# 33     Jet A1    OXIQUIM CORONEL     Coronel           Coronel
# 34     Jet A1       PLANTA PUREO     Calbuco             Pureo
# 35     Jet A1      ENAP QUINTERO         NaN          Quintero
# 36     Jet A1            BT PUMA         NaN              Puma

# %% [markdown]
# ### Paso 4:

# %% [markdown]
# Asignamos a cada par producto-planta la columna correspondiente en la planificación.

# %%
df_productos_plantas["Columna"] = ["M", "S", "Y", "AE", "BC", "BI", "BO", "BU", "CA",
                                   np.nan, "DA", np.nan, "AQ", np.nan, np.nan, np.nan, np.nan, "CK",
                                   np.nan, np.nan, np.nan, np.nan, "AW", np.nan, np.nan, np.nan, "CP",
                                   np.nan, "CU", np.nan, "AK", np.nan, np.nan, np.nan, np.nan, "CF"]

# %% [markdown]
# ### Paso 5:

# %% [markdown]
# Limpiamos el dataframe eliminando las filas sin columna asignada.

# %%
df_productos_plantas.dropna(subset=["Columna"], inplace=True)
df_productos_plantas.index = range(1, len(df_productos_plantas) + 1)
df_productos_plantas
# Out:
#      Producto             Planta      Ciudad             Alias Columna
# 1   Diesel A1     PLANTA IQUIQUE     Iquique           Iquique       M
# 2   Diesel A1  PLANTA MEJILLONES  Mejillones        Mejillones       S
# 3   Diesel A1     PLANTA CALDERA     Caldera           Caldera       Y
# 4   Diesel A1       TERMINAL TPI    Quintero               TPI      AE
# 5   Diesel A1   OXIQUIM QUINTERO    Quintero  Oxiquim Quintero      BC
# 6   Diesel A1    OXIQUIM CORONEL     Coronel           Coronel      BI
# 7   Diesel A1       PLANTA PUREO     Calbuco             Pureo      BO
# 8   Diesel A1      ENAP QUINTERO         NaN          Quintero      BU
# 9   Diesel A1            BT PUMA         NaN              Puma      CA
# 10     Gas 93  PLANTA MEJILLONES  Mejillones        Mejillones      DA
# 11     Gas 93       TERMINAL TPI    Quintero               TPI      AQ
# 12     Gas 93            BT PUMA         NaN              Puma      CK
# 13     Gas 97   OXIQUIM QUINTERO    Quintero  Oxiquim Quintero      AW
# 14     Gas 97            BT PUMA         NaN              Puma      CP
# 15     Jet A1  PLANTA MEJILLONES  Mejillones        Mejillones      CU
# 16     Jet A1       TERMINAL TPI    Quintero               TPI      AK
# 17     Jet A1            BT PUMA         NaN              Puma      CF

# %% [markdown]
# ### Paso 6:

# %% [markdown]
# Extraemos la planificación y sus respectivas descargas. Se ignoran descargas realizadas por el Puma, Enap y por puertos hacia el Puma.

# %%
FIRST_ROW = 12
LAST_ROW = 61

def extraer_planificacion(file, sheet):
    df_planificacion = pd.read_excel(file, sheet_name=sheet, header=None)
    df_planificacion.index = range(1, len(df_planificacion) + 1)
    df_planificacion.columns = [int_to_excel_col(i) for i in range(1, len(df_planificacion.columns) + 1)]

    return df_planificacion

def extraer_descargas(df_planificacion, ignore_not_bts=False, df_bts=None):
    df_descargas = pd.DataFrame({"Fecha": [], "Abrev.": [], "Volumen": [], "Columna": []})
    columnas = ["M", "S", "Y", "AE", "AK", "AQ", "AW", "BC", "BI", "BO", "BU", "CA", "CF", "CK", "CP", "CU", "DA"]
    for col in columnas:
        descargas_parciales = df_planificacion.loc[FIRST_ROW:LAST_ROW, ["B", col, next_excel_col(col)]].dropna()
        descargas_parciales.columns = ["Fecha", "Abrev.", "Volumen"]
        descargas_parciales["Columna"] = [col] * len(descargas_parciales)
        df_descargas = pd.concat([df_descargas, descargas_parciales], ignore_index=True)
    if ignore_not_bts:
        df_descargas = df_descargas[df_descargas["Abrev."].isin(df_bts["Abrev."].tolist())]
    return df_descargas

# %%
df_planificacion = extraer_planificacion(PATH_PROGRAMACION, "Planificación")
df_descargas = extraer_descargas(df_planificacion, ignore_not_bts=True, df_bts=df_bts)
df_descargas.index = range(1, len(df_descargas) + 1)
df_descargas
# Out:
# c:\Users\jaubele.ap\AppData\Local\Programs\Python\Python313\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Conditional Formatting extension is not supported and will be removed
#   warn(msg)
# c:\Users\jaubele.ap\AppData\Local\Programs\Python\Python313\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
#                   Fecha Abrev. Volumen Columna
# 1   2025-09-25 00:00:00     FE    4000       M
# 2   2025-09-26 00:00:00     FE    4000       M
# 3   2025-09-30 00:00:00     SM    6000       M
# 4   2025-10-01 00:00:00     SM    6000       M
# 5   2025-10-14 00:00:00     PK    6000       M
# ..                  ...    ...     ...     ...
# 71  2025-10-14 00:00:00     AS    9000      BI
# 72  2025-10-15 00:00:00     AS    9000      BI
# 73  2025-10-27 00:00:00     SS    7500      BI
# 74  2025-10-28 00:00:00     SS    7500      BI
# 75  2025-09-23 00:00:00     PP   15260      CK
#
# [75 rows x 4 columns]

# %% [markdown]
# ### Paso 7:

# %% [markdown]
# Mediante la el atributo "Columna" asociamos cada descarga a un par producto-planta.

# %%
df_descargas_productos_plantas = df_descargas.merge(df_productos_plantas, on=["Columna"]).drop(columns=["Columna"])
df_descargas_productos_plantas.index = range(1, len(df_descargas_productos_plantas) + 1)
df_descargas_productos_plantas
# Out:
#                   Fecha Abrev. Volumen   Producto           Planta   Ciudad  \
# 1   2025-09-25 00:00:00     FE    4000  Diesel A1   PLANTA IQUIQUE  Iquique
# 2   2025-09-26 00:00:00     FE    4000  Diesel A1   PLANTA IQUIQUE  Iquique
# 3   2025-09-30 00:00:00     SM    6000  Diesel A1   PLANTA IQUIQUE  Iquique
# 4   2025-10-01 00:00:00     SM    6000  Diesel A1   PLANTA IQUIQUE  Iquique
# 5   2025-10-14 00:00:00     PK    6000  Diesel A1   PLANTA IQUIQUE  Iquique
# ..                  ...    ...     ...        ...              ...      ...
# 71  2025-10-14 00:00:00     AS    9000  Diesel A1  OXIQUIM CORONEL  Coronel
# 72  2025-10-15 00:00:00     AS    9000  Diesel A1  OXIQUIM CORONEL  Coronel
# 73  2025-10-27 00:00:00     SS    7500  Diesel A1  OXIQUIM CORONEL  Coronel
# 74  2025-10-28 00:00:00     SS    7500  Diesel A1  OXIQUIM CORONEL  Coronel
# 75  2025-09-23 00:00:00     PP   15260     Gas 93          BT PUMA      NaN
#
#       Alias
# 1   Iquique
# 2   Iquique
# 3   Iquique
# 4   Iquique
# 5   Iquique
# ..      ...
# 71  Coronel
# 72  Coronel
# 73  Coronel
# 74  Coronel
# 75     Puma
#
# [75 rows x 7 columns]

# %% [markdown]
# ### Paso 8:

# %% [markdown]
# Mediante la abreviatura asociamos cada descarga a un programa (Por esto es importante que la abreviatura sea única, o en su defecto utilizar otro atributo de carater único como correlativo o nombre de programa).
# Se eliminarán todas las descargas que no tengan la abreviatura de un buque asociada (Ej: Caldera o TPI hacia el Puma).

# %%
df_descargas_completo = df_descargas_productos_plantas.merge(df_bts, on=["Abrev."]).drop(columns=["Abrev."])
df_descargas_completo = df_descargas_completo[["Fecha", "N° Referencia", "Nombre programa", "Nombre del BT",
                                               "Producto", "Planta", "Ciudad", "Alias", "Volumen"]]
df_descargas_completo.index = range(1, len(df_descargas_completo) + 1)
df_descargas_completo
# Out:
#                   Fecha N° Referencia          Nombre programa  \
# 1   2025-09-25 00:00:00      CC 75/25      75/25 Flora Express
# 2   2025-09-26 00:00:00      CC 75/25      75/25 Flora Express
# 3   2025-09-30 00:00:00      CC 48/25         48/25 STI Mighty
# 4   2025-10-01 00:00:00      CC 48/25         48/25 STI Mighty
# 5   2025-10-14 00:00:00      CC 50/25   50/25 Pacific Kohinoor
# ..                  ...           ...                      ...
# 71  2025-10-14 00:00:00     CC 118/25        118/25 Andean Sun
# 72  2025-10-15 00:00:00     CC 118/25        118/25 Andean Sun
# 73  2025-10-27 00:00:00     CC 130/25  130/25 Seaways Stamford
# 74  2025-10-28 00:00:00     CC 130/25  130/25 Seaways Stamford
# 75  2025-09-23 00:00:00     CC 102/25   102/25 Pintail Pacific
#
#        Nombre del BT   Producto           Planta   Ciudad    Alias Volumen
# 1      Flora Express  Diesel A1   PLANTA IQUIQUE  Iquique  Iquique    4000
# 2      Flora Express  Diesel A1   PLANTA IQUIQUE  Iquique  Iquique    4000
# 3         STI Mighty  Diesel A1   PLANTA IQUIQUE  Iquique  Iquique    6000
# 4         STI Mighty  Diesel A1   PLANTA IQUIQUE  Iquique  Iquique    6000
# 5   Pacific Kohinoor  Diesel A1   PLANTA IQUIQUE  Iquique  Iquique    6000
# ..               ...        ...              ...      ...      ...     ...
# 71        Andean Sun  Diesel A1  OXIQUIM CORONEL  Coronel  Coronel    9000
# 72        Andean Sun  Diesel A1  OXIQUIM CORONEL  Coronel  Coronel    9000
# 73  Seaways Stamford  Diesel A1  OXIQUIM CORONEL  Coronel  Coronel    7500
# 74  Seaways Stamford  Diesel A1  OXIQUIM CORONEL  Coronel  Coronel    7500
# 75   Pintail Pacific     Gas 93          BT PUMA      NaN     Puma   15260
#
# [75 rows x 9 columns]

# %% [markdown]
# ### Paso 9:

# %% [markdown]
# Agrupamos todas las descargas de un programa que son en días consecutivos de un mismo producto y en una misma planta como una sola descarga.

# %% [markdown]
# Podemos notar que Seaways Kenosha y Seaways Kolberg quedan asociados a la misma descarga (cuando realmente solo corresponde al Kolberg).

# %%
def agrupar_descargas(df_descargas_completo):
    df = df_descargas_completo.copy()
    df["Fecha"] = pd.to_datetime(df["Fecha"])
    df["diff"] = (df.groupby(["Nombre programa", "Producto", "Planta"])["Fecha"].diff().dt.days)
    df["Grupo"] = (df["diff"] != 1).cumsum()
    df_descargas_agrupadas = (df.groupby("Grupo", as_index=False).agg({"Fecha": ["min", "max"],
                                                                       "Volumen": "sum"}))
    df_descargas_agrupadas.columns = ["Grupo", "Fecha inicio", "Fecha fin", "Volumen total"]
    df_descargas_completo_sin_duplicados = df.drop_duplicates(subset=["Grupo"])
    df_descargas_agrupadas = df_descargas_agrupadas.merge(
        df_descargas_completo_sin_duplicados, on="Grupo").drop(columns=["diff", "Fecha", "Volumen"])
    df_descargas_agrupadas = df_descargas_agrupadas[[
        "Nombre programa", "N° Referencia", "Nombre del BT", "Producto", "Planta", "Ciudad", "Alias",
        "Fecha inicio", "Fecha fin", "Volumen total"]]

    # Ordenar por Nombre programa y Fecha inicio, y agregar N° Descarga
    df_descargas_agrupadas = df_descargas_agrupadas.sort_values(by=["Nombre programa", "Fecha inicio"])
    df_descargas_agrupadas["N° Descarga"] = (df_descargas_agrupadas.groupby("Nombre programa").cumcount() + 1)
    df_descargas_agrupadas.index = range(1, len(df_descargas_agrupadas) + 1) 
    return df_descargas_agrupadas

# %%
df_descargas_agrupadas = agrupar_descargas(df_descargas_completo)
df_descargas_agrupadas
# Out:
#                          Nombre programa N° Referencia  \
# 1                 102/25 Pintail Pacific     CC 102/25
# 2                 102/25 Pintail Pacific     CC 102/25
# 3   103/25 Seaways Wheat /High Challenge     CC 103/25
# 4   103/25 Seaways Wheat /High Challenge     CC 103/25
# 5                      118/25 Andean Sun     CC 118/25
# 6                      118/25 Andean Sun     CC 118/25
# 7                  119/25 Seaways Dwarka     CC 119/25
# 8                  119/25 Seaways Dwarka     CC 119/25
# 9                130/25 Seaways Stamford     CC 130/25
# 10               130/25 Seaways Stamford     CC 130/25
# 11                          139/25 TBN 1     CC 139/25
# 12                          139/25 TBN 1     CC 139/25
# 13                          19/25 Cururo      CC 19/25
# 14                          19/25 Cururo      CC 19/25
# 38               TPI   2025-10-11 2025-10-13         48000            1

# %% [markdown]
# ### Paso 10:

# %% [markdown]
# Extraemos todos los programas de la planificación.

# %%
def extraer_programas(df_planificacion):
    df_programas = df_planificacion.loc[FIRST_ROW:LAST_ROW, ["B", "J"]].dropna()
    df_programas.columns = ["ETA", "Nombre programa"]
    df_programas["ETA"] = pd.to_datetime(df_programas["ETA"]).apply(lambda dt: dt.replace(hour=0, minute=0, second=0) if pd.notna(dt) else dt)

    return df_programas

# %%
df_programas = extraer_programas(df_planificacion)
df_programas.index = range(1, len(df_programas) + 1)
df_programas
# Out:
#           ETA                       Nombre programa
# 1  2025-09-25                   75/25 Flora Express
# 2  2025-09-29                      48/25 STI Mighty
# 3  2025-10-01                  21/25 Seaways Athens
# 4  2025-10-06                     118/25 Andean Sun
# 5  2025-10-07                49/25 Pacific Sentinel
# 6  2025-10-10                     90/25 Dat Mercury
# 7  2025-10-13                50/25 Pacific Kohinoor
# 8  2025-10-14                 20/25 Seaways Kolberg
# 9  2025-10-15                    74/25 Gem Sapphire
# 10 2025-10-16               130/25 Seaways Stamford
# 11 2025-10-21                      51/25 Jag Prachi
# 12 2025-10-22                 119/25 Seaways Dwarka
# 13 2025-10-23  103/25 Seaways Wheat /High Challenge
# 14 2025-10-28                          139/25 TBN 1
# 15 2025-10-29                22/25 Meridian Express
# 16 2025-10-30              52/25 Challenge Pinnacle

# %% [markdown]
# ### Paso 11:

# %% [markdown]
# Asociamos a cada programa sus respectivas descargas, agregamos la ETA a la primera descarga de cada programa.

# %% [markdown]
# * Nota Importante: Esto ignorará todas las descargas asociadas a programas cuya ETA estimada sea anterior al inicio de la programación.

# %%
df_descargas_agrupadas = df_programas.merge(df_descargas_agrupadas, on="Nombre programa")
df_descargas_agrupadas["ETA"] = df_descargas_agrupadas["ETA"][[True if descarga == 1 else False for descarga in df_descargas_agrupadas["N° Descarga"]]]
df_descargas_agrupadas.index = range(1, len(df_descargas_agrupadas) + 1)
df_descargas_agrupadas
# Out:
#           ETA                       Nombre programa N° Referencia  \
# 1  2025-09-25                   75/25 Flora Express      CC 75/25
# 2         NaT                   75/25 Flora Express      CC 75/25
# 3  2025-09-29                      48/25 STI Mighty      CC 48/25
# 4         NaT                      48/25 STI Mighty      CC 48/25
# 5  2025-10-01                  21/25 Seaways Athens      CC 21/25
# 6         NaT                  21/25 Seaways Athens      CC 21/25
# 7  2025-10-06                     118/25 Andean Sun     CC 118/25
# 8         NaT                     118/25 Andean Sun     CC 118/25
# 9  2025-10-07                49/25 Pacific Sentinel      CC 49/25
# 10        NaT                49/25 Pacific Sentinel      CC 49/25
# 11 2025-10-10                     90/25 Dat Mercury      CC 90/25
# 12 2025-10-13                50/25 Pacific Kohinoor      CC 50/25
# 13        NaT                50/25 Pacific Kohinoor      CC 50/25
# 14 2025-10-14                 20/25 Seaways Kolberg      CC 20/25
# 15        NaT                 20/25 Seaways Kolberg      CC 20/25
# 16 2025-10-15                    74/25 Gem Sapphire      CC 74/25
express  Diesel A1     PLANTA IQUIQUE     Iquique
# 30             Challenge Pinnacle  Diesel A1       TERMINAL TPI    Quintero
# 31             Challenge Pinnacle  Diesel A1     PLANTA CALDERA     Caldera
#
#                Alias Fecha inicio  Fecha fin Volumen total  N° Descarga
# 1            Iquique   2025-09-25 2025-09-26          8000            1
# 2                TPI   2025-10-03 2025-10-04         42398            2
# 3            Iquique   2025-09-30 2025-10-01         12000            1
# 4         Mejillones   2025-10-04 2025-10-05         36000            2
# 5   Oxiquim Quintero   2025-10-04 2025-10-05         15000            1
# 6                TPI   2025-10-07 2025-10-08         33000            2
# 7         Mejillones   2025-10-09 2025-10-10         30000            1
# 8            Coronel   2025-10-14 2025-10-15         18000            2
# 9            Caldera   2025-10-09 2025-10-10         12000            1
# 10        Mejillones   2025-10-14 2025-10-15         36000            2
# 11               TPI   2025-10-11 2025-10-13         48000            1
# 12           Iquique   2025-10-14 2025-10-15         12000            1
# 13               TPI   2025-10-18 2025-10-19         36000            2
# 14               TPI   2025-10-14 2025-10-15         24000            1
# 15        Mejillones   2025-10-18 2025-10-19         24000            2
# 16           Caldera   2025-10-16 2025-10-17         12000            1
# 17        Mejillones   2025-10-23 2025-10-24         36000            2
# 18               TPI   2025-10-23 2025-10-24         32000            1
# 19           Coronel   2025-10-27 2025-10-28         15000            2
# 20           Caldera   2025-10-25 2025-10-26         12000            1
# 21               TPI   2025-10-28 2025-10-29         36000            2
# 22           Iquique   2025-10-23 2025-10-24         12000            1
# 23        Mejillones   2025-10-28 2025-10-29         36000            2
# 24  Oxiquim Quintero   2025-10-23 2025-10-24          8000            1
# 25               TPI   2025-10-28 2025-10-29         40000            2
# 26               TPI   2025-11-01 2025-11-02         24000            1
# 27        Mejillones   2025-11-07 2025-11-08         24000            2
# 28        Mejillones   2025-11-02 2025-11-03         36000            1
# 29           Iquique   2025-11-06 2025-11-07         12000            2
# 30               TPI   2025-11-06 2025-11-07         36000            1
# 31           Caldera   2025-11-08 2025-11-09         12000            2

# %% [markdown]
# ### Paso 12:

# %% [markdown]
# Extraer matriz de distancias y pasar a tiempos aproximando en horas al entero superior

# %%
def extraer_tiempos_de_viaje(file, sheet):
    VELOCIDAD_MEDIA = 12  # nudos
    df_distancias = pd.read_excel(file, sheet_name=sheet, header=3, index_col=0)
    df_distancias.dropna(axis=1, how='all', inplace=True)
    df_distancias.dropna(axis=0, how='all', inplace=True)
    matriz_de_tiempos = np.ceil(df_distancias / VELOCIDAD_MEDIA).astype(int)
    return matriz_de_tiempos

# %%
matriz_de_tiempos = extraer_tiempos_de_viaje(PATH_DISTANCIAS, "Datos")
matriz_de_tiempos
# Out:
#               ARICA  IQUIQUE  TOCOPILLA  MEJILLONES  ANTOFAGASTA  BARQUITO  \
# Arica             0        9         19          24           28        40
# Iquique           9        0         10          15           19        32
# Tocopilla        19       10          0           6           10        23
# Mejillones       24       15          6           0            6        19
# Antofagasta      28       19         10           6            0        15
# Barquito         40       32         23          19           15         0
# Caldera          44       35         26          22           18         5
# Huasco           51       43         33          30           26        12
# Guayacan         59       51         41          38           34        20
# Quintero         73       64         55          51           48        33
# San Vicente      93       85         75          72           68        54
# Coronel          95       87         77          74           70        56
# Puerto Montt    124      116        107         102           99        86
# Calbuco         122      113        104         100           97        83
# Chacabuco       141      133        123         119          116       102
# Punta Arenas    192      183        174         170          166       153
# Cabo Negro      193      185        175         172          168       154
#
#               CALDERA  HUASCO  GUAYACAN  QUINTERO  SAN VICENTE  CORONEL  \
# Arica              44      51        59        73           93       95
# Iquique            35      43        51        64           85       87
# Tocopilla          26      33        41        55           75       77
# Mejillones         22      30        38        51           72       74
# Antofagasta        18      26        34        48           68       70
# Barquito            5      12        20        33           54       56
# Caldera             0       8        17        31           51       53
# Huasco              8       0         9        23           44       46
# Guayacan           17       9         0        16           36       38
# Quintero           31      23        16         0           22       24
# San Vicente        51      44        36        22            0        3
# Coronel            53      46        38        24            3        0
# Puerto Montt       82      75        67        54           33       32
# Calbuco            80      72        65        51           31       30
# Chacabuco          99      92        84        70           50       49
# Punta Arenas      149     142       135       121          100       99
# Cabo Negro        151     143       136       122          102      101
#
#               PUERTO MONTT  CALBUCO  CHACABUCO  PUNTA ARENAS  CABO NEGRO
# Arica                  124      122        141           192         193
# Iquique                116      113        133           183         185
# Tocopilla              107      104        123           174         175
# Mejillones             102      100        119           170         172
# Antofagasta             99       97        116           166         168
# Barquito                86       83        102           153         154
# Caldera                 82       80         99           149         151
# Huasco                  75       72         92           142         143
# Guayacan                67       65         84           135         136
# Quintero                54       51         70           121         122
# San Vicente             33       31         50           100         102
# Coronel                 32       30         49            99         101
# Puerto Montt             0        2         63            78          79
# Calbuco                  2        0         21            76          77
# Chacabuco               63       21          0            63          65
# Punta Arenas            78       76         63             0           2
# Cabo Negro              79       77         65             2           0

# %% [markdown]
# ### Paso 13:

# %% [markdown]
# Calcular ETAs según matriz de tiempos

# %%
def rellenar_etas(df_descargas_agrupadas, matriz_de_tiempos):
    for programa, group in df_descargas_agrupadas.groupby('Nombre programa'):
        group = group.sort_values('N° Descarga').copy()
        for i in range(len(group)):
            if pd.isna(group.iloc[i]['ETA']):
                if i == 0:
                    continue  # No se puede calcular ETA para la primera descarga sin ETA
                prev = group.iloc[i-1]
                ciudad_origen = prev['Ciudad']
                ciudad_destino = group.iloc[i]['Ciudad']

                # Hora de salida: fecha fin anterior a las 23:00
                hora_salida = prev['Fecha fin'].replace(hour=23, minute=0, second=0)
                
                # Si alguna ciudad es NaN (probablemente PUMA o ENAP), tiempo de viaje 0.
                if pd.isna(ciudad_origen) or pd.isna(ciudad_destino):
                    df_descargas_agrupadas.loc[group.index[i], 'ETA'] = hora_salida
                    continue
                horas_viaje = matriz_de_tiempos.loc[ciudad_origen, ciudad_destino.upper()]
                df_descargas_agrupadas.loc[group.index[i], 'ETA'] = hora_salida + timedelta(hours=int(horas_viaje))

# %%
rellenar_etas(df_descargas_agrupadas, matriz_de_tiempos)
df_descargas_agrupadas
# Out:
#                    ETA                       Nombre programa N° Referencia  \
# 26               TPI   2025-11-01 2025-11-02         24000            1
# 27        Mejillones   2025-11-07 2025-11-08         24000            2
# 28        Mejillones   2025-11-02 2025-11-03         36000            1
# 29           Iquique   2025-11-06 2025-11-07         12000            2
# 30               TPI   2025-11-06 2025-11-07         36000            1
# 31           Caldera   2025-11-08 2025-11-09         12000            2

# %% [markdown]
# ### Paso 14:

# %% [markdown]
# Ajustamos al formato de la Base de Datos.

# %%
df_BD = df_descargas_agrupadas[["N° Referencia", "Nombre del BT", "Producto", "Alias", "Volumen total", "ETA", "Fecha fin"]]
df_BD.columns = ["CC", "Nombre BT", "Producto", "Puerto", "Volumen", "ETA", "Fin descarga"]
df_BD
# Out:
#            CC                      Nombre BT   Producto            Puerto  \
# 1    CC 75/25                  Flora Express  Diesel A1           Iquique
# 2    CC 75/25                  Flora Express  Diesel A1               TPI
# 3    CC 48/25                     STI Mighty  Diesel A1           Iquique
# 4    CC 48/25                     STI Mighty  Diesel A1        Mejillones
# 5    CC 21/25                 Seaways Athens  Diesel A1  Oxiquim Quintero
# 6    CC 21/25                 Seaways Athens  Diesel A1               TPI
# 7   CC 118/25                     Andean Sun  Diesel A1        Mejillones
# 8   CC 118/25                     Andean Sun  Diesel A1           Coronel
# 9    CC 49/25               Pacific Sentinel  Diesel A1           Caldera
# 10   CC 49/25               Pacific Sentinel  Diesel A1        Mejillones
# 11   CC 90/25                    Dat Mercury     Jet A1               TPI
# 12   CC 50/25               Pacific Kohinoor  Diesel A1           Iquique
# 13   CC 50/25               Pacific Kohinoor  Diesel A1               TPI
# 14   CC 20/25                Seaways Kolberg  Diesel A1               TPI
# 15   CC 20/25                Seaways Kolberg  Diesel A1        Mejillones
# 16   CC 74/25                   Gem Sapphire  Diesel A1           Caldera
# 17   CC 74/25                   Gem Sapphire  Diesel A1        Mejillones
# 18  CC 130/25               Seaways Stamford  Diesel A1               TPI
# 19  CC 130/25               Seaways Stamford  Diesel A1           Coronel
# 20   CC 51/25                     Jag Prachi  Diesel A1           Caldera
# 21   CC 51/25                     Jag Prachi  Diesel A1               TPI
# 22  CC 119/25                 Seaways Dwarka  Diesel A1           Iquique
# 23  CC 119/25                 Seaways Dwarka  Diesel A1        Mejillones
# 24  CC 103/25  Seaways Wheat /High Challenge     Gas 97  Oxiquim Quintero
# 25  CC 103/25  Seaways Wheat /High Challenge     Gas 93               TPI
# 26  CC 139/25                          TBN 1  Diesel A1               TPI
# 27  CC 139/25                          TBN 1  Diesel A1        Mejillones
# 28   CC 22/25               Meridian Express  Diesel A1        Mejillones
# 29   CC 22/25               Meridian Express  Diesel A1           Iquique
# 30   CC 52/25             Challenge Pinnacle  Diesel A1               TPI
# 31   CC 52/25             Challenge Pinnacle  Diesel A1           Caldera
#
#    Volumen                 ETA Fin descarga
# 1     8000 2025-09-25 00:00:00   2025-09-26
# 2    42398 2025-09-29 15:00:00   2025-10-04
# 3    12000 2025-09-29 00:00:00   2025-10-01
# 4    36000 2025-10-02 14:00:00   2025-10-05
# 5    15000 2025-10-01 00:00:00   2025-10-05
# 6    33000 2025-10-05 23:00:00   2025-10-08
# 7    30000 2025-10-06 00:00:00   2025-10-10
# 8    18000 2025-10-14 01:00:00   2025-10-15
# 9    12000 2025-10-07 00:00:00   2025-10-10
# 10   36000 2025-10-11 21:00:00   2025-10-15
# 11   48000 2025-10-10 00:00:00   2025-10-13
# 12   12000 2025-10-13 00:00:00   2025-10-15
# 13   36000 2025-10-18 15:00:00   2025-10-19
# 14   24000 2025-10-14 00:00:00   2025-10-15
# 15   24000 2025-10-18 02:00:00   2025-10-19
# 16   12000 2025-10-15 00:00:00   2025-10-17
# 17   36000 2025-10-18 21:00:00   2025-10-24
# 18   32000 2025-10-16 00:00:00   2025-10-24
# 19   15000 2025-10-25 23:00:00   2025-10-28
# 20   12000 2025-10-21 00:00:00   2025-10-26
# 21   36000 2025-10-28 06:00:00   2025-10-29
# 22   12000 2025-10-22 00:00:00   2025-10-24
# 23   36000 2025-10-25 14:00:00   2025-10-29
# 24    8000 2025-10-23 00:00:00   2025-10-24
# 25   40000 2025-10-24 23:00:00   2025-10-29
# 26   24000 2025-10-28 00:00:00   2025-11-02
# 27   24000 2025-11-05 02:00:00   2025-11-08
# 28   36000 2025-10-29 00:00:00   2025-11-03
# 29   12000 2025-11-04 14:00:00   2025-11-07
# 30   36000 2025-10-30 00:00:00   2025-11-07
# 31   12000 2025-11-09 06:00:00   2025-11-09

# %% [markdown]
# ## Parte 2:

# %% [markdown]
# Agregar campos de Proveedor, Inicio Ventana, Final Ventana.

# %%
PATH_NUEVA_FICHA = "Nueva Ficha Información de Buques.xlsx"

# %%
def extraer_nueva_ficha(file, sheet):
    df_nueva_ficha = pd.read_excel(file, sheet_name=sheet, header=3)
    df_nueva_ficha = df_nueva_ficha[["N° Referencia", "Proveedor", "Inicio Ventana",
                                     "Fin Ventana", "Inicio Ventana Corta", "Fin Ventana Corta",
                                     "MONTO ($/DIA)"]]
    df_nueva_ficha.drop_duplicates(subset=["N° Referencia"], keep="first", inplace=True)
    
    return df_nueva_ficha

# %%
df_nueva_ficha = extraer_nueva_ficha(PATH_NUEVA_FICHA, "Programación de buques")
df_nueva_ficha = df_nueva_ficha[df_nueva_ficha["N° Referencia"].isin(df_BD["CC"])]
df_nueva_ficha.index = range(1, len(df_nueva_ficha) + 1)
df_nueva_ficha
# Out:
#    N° Referencia    Proveedor Inicio Ventana          Fin Ventana  \
# 1       CC 20/25       ARAMCO     2025-09-22  2025-09-26 00:00:00
# 2       CC 75/25  PHILLIPS 66     2025-09-22  2025-09-26 00:00:00
# 3       CC 21/25       ARAMCO     2025-09-29  2025-10-03 00:00:00
# 4       CC 48/25      CHEVRON     2025-09-29  2025-10-03 00:00:00
# 5       CC 49/25      CHEVRON     2025-10-06  2025-10-10 00:00:00
# 6      CC 118/25       ARAMCO     2025-10-06  2025-10-10 00:00:00
# 7       CC 90/25      CHEVRON     2025-10-08  2025-10-12 00:00:00
# 8       CC 50/25      CHEVRON     2025-10-13  2025-10-17 00:00:00
# 9       CC 74/25     MARATHON     2025-10-13  2025-10-17 00:00:00
# 10     CC 130/25       ARAMCO     2025-10-13  2025-10-17 00:00:00
# 11      CC 51/25      CHEVRON     2025-10-20  2025-10-24 00:00:00
# 12     CC 119/25    BB ENERGY     2025-10-20  2025-10-24 00:00:00
# 13     CC 103/25        VITOL     2025-10-20  2025-10-24 00:00:00
# 14      CC 22/25       ARAMCO     2025-10-27  2025-10-31 00:00:00
# 15      CC 52/25      CHEVRON     2025-10-27  2025-10-31 00:00:00
# 16     CC 139/25      CHEVRON     2025-10-27  2025-10-31 00:00:00
#
#    Inicio Ventana Corta    Fin Ventana Corta MONTO ($/DIA)
# 1   2025-09-24 00:00:00  2025-09-26 00:00:00         34500
# 2   2025-09-24 00:00:00  2025-09-26 00:00:00         32000
# 3   2025-10-01 00:00:00  2025-10-03 00:00:00         34000
# 4   2025-09-29 00:00:00  2025-10-01 00:00:00         40000
# 5             Pendiente            Pendiente         40000
# 6             Pendiente            Pendiente         33000
# 7             Pendiente            Pendiente         40000
# 8             Pendiente            Pendiente         33000
# 9             Pendiente            Pendiente           NaN
# 10            Pendiente            Pendiente         35000
# 11            Pendiente            Pendiente         35000
# 12            Pendiente            Pendiente         32000
# 13            Pendiente            Pendiente         30000
# 14            Pendiente            Pendiente         37500
# 15            Pendiente            Pendiente         27500
# 16            Pendiente            Pendiente           NaN

# %% [markdown]
# Establecemos la ventana corta como la ventana e caso de existir, en otro caso se conserva la ventana original.

# %%
for col in ["Inicio Ventana Corta", "Fin Ventana Corta"]:
    df_nueva_ficha[col] = pd.to_datetime(df_nueva_ficha[col], errors="coerce")

df_nueva_ficha["Inicio Ventana"] = df_nueva_ficha["Inicio Ventana Corta"].combine_first(pd.to_datetime(df_nueva_ficha["Inicio Ventana"]))
df_nueva_ficha["Final Ventana"] = df_nueva_ficha["Fin Ventana Corta"].combine_first(pd.to_datetime(df_nueva_ficha["Fin Ventana"]))
df_nueva_ficha.drop(columns=["Fin Ventana"], inplace=True)

# Eliminar columnas de ventanas cortas
df_nueva_ficha = df_nueva_ficha.drop(columns=["Inicio Ventana Corta", "Fin Ventana Corta"])
df_nueva_ficha
# Out:
#    N° Referencia    Proveedor Inicio Ventana MONTO ($/DIA) Final Ventana
# 1       CC 20/25       ARAMCO     2025-09-24         34500    2025-09-26
# 2       CC 75/25  PHILLIPS 66     2025-09-24         32000    2025-09-26
# 3       CC 21/25       ARAMCO     2025-10-01         34000    2025-10-03
# 4       CC 48/25      CHEVRON     2025-09-29         40000    2025-10-01
# 5       CC 49/25      CHEVRON     2025-10-06         40000    2025-10-10
# 6      CC 118/25       ARAMCO     2025-10-06         33000    2025-10-10
# 7       CC 90/25      CHEVRON     2025-10-08         40000    2025-10-12
# 8       CC 50/25      CHEVRON     2025-10-13         33000    2025-10-17
# 9       CC 74/25     MARATHON     2025-10-13           NaN    2025-10-17
# 10     CC 130/25       ARAMCO     2025-10-13         35000    2025-10-17
# 11      CC 51/25      CHEVRON     2025-10-20         35000    2025-10-24
# 12     CC 119/25    BB ENERGY     2025-10-20         32000    2025-10-24
# 13     CC 103/25        VITOL     2025-10-20         30000    2025-10-24
# 14      CC 22/25       ARAMCO     2025-10-27         37500    2025-10-31
# 15      CC 52/25      CHEVRON     2025-10-27         27500    2025-10-31
# 16     CC 139/25      CHEVRON     2025-10-27           NaN    2025-10-31

# %%
df_BD = df_BD.merge(df_nueva_ficha, left_on="CC", right_on="N° Referencia").drop(columns=["N° Referencia"])
df_BD = df_BD[["CC", "Nombre BT", "Proveedor", "Producto", "Puerto", "Volumen", "Inicio Ventana", "Final Ventana", "ETA", "Fin descarga"]]
df_BD.index = range(1, len(df_BD) + 1)
df_BD
# Out:
#            CC                      Nombre BT    Proveedor   Producto  \
# 1    CC 75/25                  Flora Express  PHILLIPS 66  Diesel A1
# 2    CC 75/25                  Flora Express  PHILLIPS 66  Diesel A1
# 3    CC 48/25                     STI Mighty      CHEVRON  Diesel A1
# 4    CC 48/25                     STI Mighty      CHEVRON  Diesel A1
# 5    CC 21/25                 Seaways Athens       ARAMCO  Diesel A1
# 6    CC 21/25                 Seaways Athens       ARAMCO  Diesel A1
# 7   CC 118/25                     Andean Sun       ARAMCO  Diesel A1
# 8   CC 118/25                     Andean Sun       ARAMCO  Diesel A1
# 9    CC 49/25               Pacific Sentinel      CHEVRON  Diesel A1
# 10   CC 49/25               Pacific Sentinel      CHEVRON  Diesel A1
# 11   CC 90/25                    Dat Mercury      CHEVRON     Jet A1
# 12   CC 50/25               Pacific Kohinoor      CHEVRON  Diesel A1
# 13   CC 50/25               Pacific Kohinoor      CHEVRON  Diesel A1
# 14   CC 20/25                Seaways Kolberg       ARAMCO  Diesel A1
# 15   CC 20/25                Seaways Kolberg       ARAMCO  Diesel A1
# 16   CC 74/25                   Gem Sapphire     MARATHON  Diesel A1
# 17   CC 74/25                   Gem Sapphire     MARATHON  Diesel A1
# 18  CC 130/25               Seaways Stamford       ARAMCO  Diesel A1
# 19  CC 130/25               Seaways Stamford       ARAMCO  Diesel A1
# 20   CC 51/25                     Jag Prachi      CHEVRON  Diesel A1
# 21   CC 51/25                     Jag Prachi      CHEVRON  Diesel A1
# 22  CC 119/25                 Seaways Dwarka    BB ENERGY  Diesel A1
# 23  CC 119/25                 Seaways Dwarka    BB ENERGY  Diesel A1
# 24  CC 103/25  Seaways Wheat /High Challenge        VITOL     Gas 97
# 25  CC 103/25  Seaways Wheat /High Challenge        VITOL     Gas 93
# 26  CC 139/25                          TBN 1      CHEVRON  Diesel A1
# 27  CC 139/25                          TBN 1      CHEVRON  Diesel A1
# 28   CC 22/25               Meridian Express       ARAMCO  Diesel A1
# 29   CC 22/25               Meridian Express       ARAMCO  Diesel A1
# 30   CC 52/25             Challenge Pinnacle      CHEVRON  Diesel A1
# 31   CC 52/25             Challenge Pinnacle      CHEVRON  Diesel A1
#
#               Puerto Volumen Inicio Ventana Final Ventana                 ETA  \
# 27   2025-11-08
# 28   2025-11-03
# 29   2025-11-07
# 30   2025-11-07
# 31   2025-11-09

# %% [markdown]
# ## Parte 3:

# %% [markdown]
# Se agrega fecha de programación y se calcula la semana de manera automática. En la app se selecciona a través de un form.

# %%
def get_week_of_month(year, month, day):
    month_calendar = calendar.monthcalendar(year, month)
    for week_number, week in enumerate(month_calendar, start=1):
        if day in week:
            return "Semana " + str(week_number)

# %%
FECHA_PROGRAMACION = pd.to_datetime("2025-09-24")  # Ejemplo, en la app se selecciona a través de un form
columnas_vacias = ["Fecha de programación", "Semana", "Año", "Mes", "Horas Laytime", 
                "Demurrage"]
for col in columnas_vacias:
    df_BD[col] = [np.nan] * len(df_BD)

df_BD["Fecha de programación"] = FECHA_PROGRAMACION
df_BD["Semana"] = get_week_of_month(FECHA_PROGRAMACION.year, FECHA_PROGRAMACION.month, FECHA_PROGRAMACION.day)

# Reordenar columnas
df_BD = df_BD[["Fecha de programación", "Semana", "Año", "Mes", "Horas Laytime",
            "CC", "Nombre BT", "Proveedor", "Producto", "Demurrage", "Puerto",
            "Volumen", "Inicio Ventana", "Final Ventana", "ETA", "Fin descarga"]]
df_BD
# Out:
#    Fecha de programación    Semana  Año  Mes  Horas Laytime         CC  \
# 1             2025-09-24  Semana 4  NaN  NaN            NaN   CC 75/25
# 2             2025-09-24  Semana 4  NaN  NaN            NaN   CC 75/25
# 3             2025-09-24  Semana 4  NaN  NaN            NaN   CC 48/25
# 4             2025-09-24  Semana 4  NaN  NaN            NaN   CC 48/25
# 5             2025-09-24  Semana 4  NaN  NaN            NaN   CC 21/25
# 6             2025-09-24  Semana 4  NaN  NaN            NaN   CC 21/25
# 7             2025-09-24  Semana 4  NaN  NaN            NaN  CC 118/25
# 8             2025-09-24  Semana 4  NaN  NaN            NaN  CC 118/25
# 9             2025-09-24  Semana 4  NaN  NaN            NaN   CC 49/25
# 10            2025-09-24  Semana 4  NaN  NaN            NaN   CC 49/25
# 11            2025-09-24  Semana 4  NaN  NaN            NaN   CC 90/25
# 12            2025-09-24  Semana 4  NaN  NaN            NaN   CC 50/25
# 13            2025-09-24  Semana 4  NaN  NaN            NaN   CC 50/25
# 14            2025-09-24  Semana 4  NaN  NaN            NaN   CC 20/25
# 15            2025-09-24  Semana 4  NaN  NaN            NaN   CC 20/25
# 16            2025-09-24  Semana 4  NaN  NaN            NaN   CC 74/25
# 17            2025-09-24  Semana 4  NaN  NaN            NaN   CC 74/25
# 18            2025-09-24  Semana 4  NaN  NaN            NaN  CC 130/25
# 19            2025-09-24  Semana 4  NaN  NaN            NaN  CC 130/25
# 20            2025-09-24  Semana 4  NaN  NaN            NaN   CC 51/25
# 21            2025-09-24  Semana 4  NaN  NaN            NaN   CC 51/25
# 22            2025-09-24  Semana 4  NaN  NaN            NaN  CC 119/25
# 23            2025-09-24  Semana 4  NaN  NaN            NaN  CC 119/25
# 24            2025-09-24  Semana 4  NaN  NaN            NaN  CC 103/25
# 25            2025-09-24  Semana 4  NaN  NaN            NaN  CC 103/25
# 26            2025-09-24  Semana 4  NaN  NaN            NaN  CC 139/25
# 27            2025-09-24  Semana 4  NaN  NaN            NaN  CC 139/25
# 28            2025-09-24  Semana 4  NaN  NaN            NaN   CC 22/25
# 29            2025-09-24  Semana 4  NaN  NaN            NaN   CC 22/25
# 30            2025-09-24  Semana 4  NaN  NaN            NaN   CC 52/25
# 31            2025-09-24  Semana 4  NaN  NaN            NaN   CC 52/25
#
#                         Nombre BT    Proveedor   Producto  Demurrage  \
# 1                   Flora Express  PHILLIPS 66  Diesel A1        NaN
# 2                   Flora Express  PHILLIPS 66  Diesel A1        NaN
# 3                      STI Mighty      CHEVRON  Diesel A1        NaN
# 4                      STI Mighty      CHEVRON  Diesel A1        NaN
# 5                  Seaways Athens       ARAMCO  Diesel A1        NaN
# 6                  Seaways Athens       ARAMCO  Diesel A1        NaN
# 7                      Andean Sun       ARAMCO  Diesel A1        NaN
# 8                      Andean Sun       ARAMCO  Diesel A1        NaN
# 9                Pacific Sentinel      CHEVRON  Diesel A1        NaN
# 10               Pacific Sentinel      CHEVRON  Diesel A1        NaN
# 11                    Dat Mercury      CHEVRON     Jet A1        NaN
# 12               Pacific Kohinoor      CHEVRON  Diesel A1        NaN
# 13               Pacific Kohinoor      CHEVRON  Diesel A1        NaN
# 14                Seaways Kolberg       ARAMCO  Diesel A1        NaN
# 15                Seaways Kolberg       ARAMCO  Diesel A1        NaN
# 16                   Gem Sapphire     MARATHON  Diesel A1        NaN
# 17                   Gem Sapphire     MARATHON  Diesel A1        NaN
# 18               Seaways Stamford       ARAMCO  Diesel A1        NaN
# 19               Seaways Stamford       ARAMCO  Diesel A1        NaN
# 20                     Jag Prachi      CHEVRON  Diesel A1        NaN
# 21                     Jag Prachi      CHEVRON  Diesel A1        NaN
# 22                 Seaways Dwarka    BB ENERGY  Diesel A1        NaN
# 23                 Seaways Dwarka    BB ENERGY  Diesel A1        NaN
# 24  Seaways Wheat /High Challenge        VITOL     Gas 97        NaN
# 25  Seaways Wheat /High Challenge        VITOL     Gas 93        NaN
# 26                          TBN 1      CHEVRON  Diesel A1        NaN
# 27                          TBN 1      CHEVRON  Diesel A1        NaN
# 28               Meridian Express       ARAMCO  Diesel A1        NaN
# 29               Meridian Express       ARAMCO  Diesel A1        NaN
# 30             Challenge Pinnacle      CHEVRON  Diesel A1        NaN
# 31             Challenge Pinnacle      CHEVRON  Diesel A1        NaN
#
#               Puerto Volumen Inicio Ventana Final Ventana                 ETA  \
# 1            Iquique    8000     2025-09-24    2025-09-26 2025-09-25 00:00:00
# 2                TPI   42398     2025-09-24    2025-09-26 2025-09-29 15:00:00
# 3            Iquique   12000     2025-09-29    2025-10-01 2025-09-29 00:00:00
# 4         Mejillones   36000     2025-09-29    2025-10-01 2025-10-02 14:00:00
# 5   Oxiquim Quintero   15000     2025-10-01    2025-10-03 2025-10-01 00:00:00
# 6                TPI   33000     2025-10-01    2025-10-03 2025-10-05 23:00:00
         9: "Septiembre", 10: "Octubre", 11: "Noviembre", 12: "Diciembre"}

# %%
def asignar_año_mes(df_descargas_completo, df_BD):
    df = df_descargas_completo.copy()
    df["Fecha"] = pd.to_datetime(df["Fecha"])
    df["Mes_Año"] = df["Fecha"].dt.to_period("M")
    vol_por_mes = df.groupby(["N° Referencia", "Mes_Año"], as_index=False)["Volumen"].sum()
    mes_mayor_volumen = vol_por_mes.loc[vol_por_mes.groupby("N° Referencia")["Volumen"].idxmax()]
    df_BD = df_BD.merge(mes_mayor_volumen[["N° Referencia", "Mes_Año"]],
                left_on="CC", right_on="N° Referencia", how="left").drop(columns=["N° Referencia"])
    df_BD["Mes"] = df_BD["Mes_Año"].dt.month
    df_BD["Año"] = df_BD["Mes_Año"].dt.year
    df_BD.drop(columns=["Mes_Año"], inplace=True)
    df_BD.index = range(1, len(df_BD) + 1)
    df_BD["Mes"] = df_BD["Mes"].map(MESES)
    
    return df_BD

# %%
df_BD = asignar_año_mes(df_descargas_completo, df_BD)
df_BD
# Out:
#    Fecha de programación    Semana   Año        Mes  Horas Laytime         CC  \
# 1             2025-09-24  Semana 4  2025    Octubre            NaN   CC 75/25
# 2             2025-09-24  Semana 4  2025    Octubre            NaN   CC 75/25
# 3             2025-09-24  Semana 4  2025    Octubre            NaN   CC 48/25
# 4             2025-09-24  Semana 4  2025    Octubre            NaN   CC 48/25
# 5             2025-09-24  Semana 4  2025    Octubre            NaN   CC 21/25
# 6             2025-09-24  Semana 4  2025    Octubre            NaN   CC 21/25
# 7             2025-09-24  Semana 4  2025    Octubre            NaN  CC 118/25
# 8             2025-09-24  Semana 4  2025    Octubre            NaN  CC 118/25
# 9             2025-09-24  Semana 4  2025    Octubre            NaN   CC 49/25
# 10            2025-09-24  Semana 4  2025    Octubre            NaN   CC 49/25
# 11            2025-09-24  Semana 4  2025    Octubre            NaN   CC 90/25
# 12            2025-09-24  Semana 4  2025    Octubre            NaN   CC 50/25
# 13            2025-09-24  Semana 4  2025    Octubre            NaN   CC 50/25
# 14            2025-09-24  Semana 4  2025    Octubre            NaN   CC 20/25
# 15            2025-09-24  Semana 4  2025    Octubre            NaN   CC 20/25
# 16            2025-09-24  Semana 4  2025    Octubre            NaN   CC 74/25
# 17            2025-09-24  Semana 4  2025    Octubre            NaN   CC 74/25
# 18            2025-09-24  Semana 4  2025    Octubre            NaN  CC 130/25
# 19            2025-09-24  Semana 4  2025    Octubre            NaN  CC 130/25
# 20            2025-09-24  Semana 4  2025    Octubre            NaN   CC 51/25
# 21            2025-09-24  Semana 4  2025    Octubre            NaN   CC 51/25
# 22            2025-09-24  Semana 4  2025    Octubre            NaN  CC 119/25
# 23            2025-09-24  Semana 4  2025    Octubre            NaN  CC 119/25
# 24            2025-09-24  Semana 4  2025    Octubre            NaN  CC 103/25
# 25            2025-09-24  Semana 4  2025    Octubre            NaN  CC 103/25
# 26            2025-09-24  Semana 4  2025  Noviembre            NaN  CC 139/25
# 27            2025-09-24  Semana 4  2025  Noviembre            NaN  CC 139/25
# 28            2025-09-24  Semana 4  2025  Noviembre            NaN   CC 22/25
# 29            2025-09-24  Semana 4  2025  Noviembre            NaN   CC 22/25
# 30            2025-09-24  Semana 4  2025  Noviembre            NaN   CC 52/25
# 31            2025-09-24  Semana 4  2025  Noviembre            NaN   CC 52/25
#
#                         Nombre BT    Proveedor   Producto  Demurrage  \
# 1                   Flora Express  PHILLIPS 66  Diesel A1        NaN
# 2                   Flora Express  PHILLIPS 66  Diesel A1        NaN
# 3                      STI Mighty      CHEVRON  Diesel A1        NaN
# 4                      STI Mighty      CHEVRON  Diesel A1        NaN
# 5                  Seaways Athens       ARAMCO  Diesel A1        NaN
# 6                  Seaways Athens       ARAMCO  Diesel A1        NaN
# 7                      Andean Sun       ARAMCO  Diesel A1        NaN
# 8                      Andean Sun       ARAMCO  Diesel A1        NaN
# 9                Pacific Sentinel      CHEVRON  Diesel A1        NaN
# 10               Pacific Sentinel      CHEVRON  Diesel A1        NaN
# 11                    Dat Mercury      CHEVRON     Jet A1        NaN
# 12               Pacific Kohinoor      CHEVRON  Diesel A1        NaN
# 13               Pacific Kohinoor      CHEVRON  Diesel A1        NaN
# 14                Seaways Kolberg       ARAMCO  Diesel A1        NaN
# 15                Seaways Kolberg       ARAMCO  Diesel A1        NaN
# 16                   Gem Sapphire     MARATHON  Diesel A1        NaN
# 17                   Gem Sapphire     MARATHON  Diesel A1        NaN
# 18               Seaways Stamford       ARAMCO  Diesel A1        NaN
# 19               Seaways Stamford       ARAMCO  Diesel A1        NaN
# 20                     Jag Prachi      CHEVRON  Diesel A1        NaN
# 21                     Jag Prachi      CHEVRON  Diesel A1        NaN
# 22                 Seaways Dwarka    BB ENERGY  Diesel A1        NaN
# 23                 Seaways Dwarka    BB ENERGY  Diesel A1        NaN
# 24  Seaways Wheat /High Challenge        VITOL     Gas 97        NaN
# 25  Seaways Wheat /High Challenge        VITOL     Gas 93        NaN
# 26                          TBN 1      CHEVRON  Diesel A1        NaN
# 27                          TBN 1      CHEVRON  Diesel A1        NaN
# 28               Meridian Express       ARAMCO  Diesel A1        NaN
# 29               Meridian Express       ARAMCO  Diesel A1        NaN
# 30             Challenge Pinnacle      CHEVRON  Diesel A1        NaN
# 31             Challenge Pinnacle      CHEVRON  Diesel A1        NaN
#
#               Puerto Volumen Inicio Ventana Final Ventana                 ETA  \
# 1            Iquique    8000     2025-09-24    2025-09-26 2025-09-25 00:00:00
# 2                TPI   42398     2025-09-24    2025-09-26 2025-09-29 15:00:00
# 3            Iquique   12000     2025-09-29    2025-10-01 2025-09-29 00:00:00
# 4         Mejillones   36000     2025-09-29    2025-10-01 2025-10-02 14:00:00
# 5   Oxiquim Quintero   15000     2025-10-01    2025-10-03 2025-10-01 00:00:00
# 6                TPI   33000     2025-10-01    2025-10-03 2025-10-05 23:00:00
# 7         Mejillones   30000     2025-10-06    2025-10-10 2025-10-06 00:00:00
# 8            Coronel   18000     2025-10-06    2025-10-10 2025-10-14 01:00:00
df_descargas_agrupadas_con_ventanas["Final Ventana"] = pd.to_datetime(df_descargas_agrupadas_con_ventanas["Final Ventana"]).apply(lambda dt: dt.replace(hour=23, minute=59, second=59) if pd.notna(dt) else dt)
df_descargas_agrupadas_con_ventanas["Fecha inicio"] = pd.to_datetime(df_descargas_agrupadas_con_ventanas["Fecha inicio"]).apply(lambda dt: dt.replace(hour=15, minute=0, second=0) if pd.notna(dt) else dt)
df_descargas_agrupadas_con_ventanas["Fecha fin"] = pd.to_datetime(df_descargas_agrupadas_con_ventanas["Fecha fin"]).apply(lambda dt: dt.replace(hour=23, minute=0, second=0) if pd.notna(dt) else dt)

# ETA en ventana o num de descarga > 1
inicio_laytime = pd.concat([
    df_descargas_agrupadas_con_ventanas['Fecha inicio'],
    df_descargas_agrupadas_con_ventanas['ETA'] + pd.Timedelta(hours=6)
], axis=1).min(axis=1)

# Condición N° de descarga = 1 y ETA < Inicio Ventana
cond = (df_descargas_agrupadas_con_ventanas['N° Descarga'] == 1) & (df_descargas_agrupadas_con_ventanas['ETA'] < df_descargas_agrupadas_con_ventanas['Inicio Ventana'])
inicio_laytime = inicio_laytime.mask(cond, pd.concat([df_descargas_agrupadas_con_ventanas['Inicio Ventana'], df_descargas_agrupadas_con_ventanas['Fecha inicio']], axis=1).min(axis=1))

# Condición N° de descarga = 1 y ETA > Final Ventana
cond = (df_descargas_agrupadas_con_ventanas['N° Descarga'] == 1) & (df_descargas_agrupadas_con_ventanas['ETA'] > df_descargas_agrupadas_con_ventanas['Final Ventana'])
inicio_laytime = inicio_laytime.mask(cond, df_descargas_agrupadas_con_ventanas['Fecha inicio'])

# Asignamos la columna final
df_descargas_agrupadas_con_ventanas['Inicio Laytime'] = inicio_laytime
df_descargas_agrupadas_con_ventanas["Laytime"] = (df_descargas_agrupadas_con_ventanas["Fecha fin"] - df_descargas_agrupadas_con_ventanas["Inicio Laytime"]).dt.total_seconds() / 3600
df_descargas_agrupadas_con_ventanas
# Out:
#                    ETA                       Nombre programa N° Referencia  \
# 0  2025-09-25 00:00:00                   75/25 Flora Express      CC 75/25
# 1  2025-09-29 15:00:00                   75/25 Flora Express      CC 75/25
# 2  2025-09-29 00:00:00                      48/25 STI Mighty      CC 48/25
# 3  2025-10-02 14:00:00                      48/25 STI Mighty      CC 48/25
# 4  2025-10-01 00:00:00                  21/25 Seaways Athens      CC 21/25
# 5  2025-10-05 23:00:00                  21/25 Seaways Athens      CC 21/25
# 6  2025-10-06 00:00:00                     118/25 Andean Sun     CC 118/25
# 7  2025-10-14 01:00:00                     118/25 Andean Sun     CC 118/25
# 8  2025-10-07 00:00:00                49/25 Pacific Sentinel      CC 49/25
# 9  2025-10-11 21:00:00                49/25 Pacific Sentinel      CC 49/25
# 10 2025-10-10 00:00:00                     90/25 Dat Mercury      CC 90/25
# 11 2025-10-13 00:00:00                50/25 Pacific Kohinoor      CC 50/25
# 12 2025-10-18 15:00:00                50/25 Pacific Kohinoor      CC 50/25
